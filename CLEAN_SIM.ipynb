# %%
import pandas as pd
import numpy as np
import os 
import plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pio
from datetime import datetime
import scipy as sp
import time
from random import random
pio.renderers.default = "iframe"

import pandas as pd
import numpy as np
import os
import plotly
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pio
from datetime import datetime
import scipy as sp
import time
import random
import pandas as pd
import numpy as np
from datetime import datetime, date, timedelta
import time 
import os
import oandapyV20
from oandapyV20 import API
import oandapyV20.endpoints.pricing as pricing
import oandapyV20.endpoints.accounts as accounts
import oandapyV20.endpoints.orders as orders
import oandapyV20.endpoints.trades as trades 
import oandapyV20.endpoints.positions as positions
import oandapyV20.endpoints.transactions as trans
import oandapyV20.endpoints.instruments as instruments
import oandapyV20.definitions.primitives as primitives
import pandas as pd
from dateutil.relativedelta import relativedelta
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus
import psycopg2
import os
import io
from io import StringIO 
import boto3
import pandas as pd
import numpy as np

import time 
import pygsheets
import datedelta
import calendar
import  csv
import json

from oandapyV20.exceptions import V20Error
from oandapyV20.endpoints.pricing import PricingStream

from scipy import stats


def create_spike_trigger(df,col = 'delta_max',lookback_threshold = 3600):
    print('CREATING SPIKE TRIGGER...')
    df[col + '_spike_trigger'] = 0
    col_loc = df.columns.get_loc(col)
    arr = df.values
    for i in range(lookback_threshold,arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            cur_max = max(arr[i - lookback_threshold : i ,col_loc])
        except:
            print('ERROR',i)
            cur_max = 100
        if arr[i,col_loc] > cur_max and sum(arr[i - 100 : i,-1]) == 0:
            arr[i,-1] = 1
    return pd.DataFrame(arr,columns = df.columns)

def create_wick_trigger(df,col = 'wick',lookback_threshold = 3600):
    
    print('CREATING WICK TRIGGER...')
    df['wick'] = 0
    df.loc[df[df['delta_vector'] < 0].index,'wick'] = df.loc[df[df['delta_vector'] < 0].index,'c'] - df.loc[df[df['delta_vector'] < 0].index,'l']
    df.loc[df[df['delta_vector'] > 0].index,'wick'] = df.loc[df[df['delta_vector'] > 0].index,'h'] - df.loc[df[df['delta_vector'] > 0].index,'c']
    df['wick_trigger'] = 0


    col_loc = df.columns.get_loc(col)
    arr = df.values
    for i in range(lookback_threshold,arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            cur_max = max(arr[i - lookback_threshold : i ,col_loc])
        except:
            print('ERROR',i)
            cur_max = 100
        if arr[i,col_loc] > cur_max and sum(arr[i - 100 : i,-1]) == 0:
            arr[i,-1] = 1
    return pd.DataFrame(arr,columns = df.columns)
def consecutive_candles(df,num = 10,col = 'delta_vector'):
    print('CREATING CONSECUTIVE CANDLES TRIGGER...')
    df[col + '_consecutive_trigger'] = 0
    col_loc = df.columns.get_loc(col)
    arr = df.values
    last = -1
    counter = 0
    for i in range(arr.shape[0]):
        
        if i % 200000 == 0:
            print(i)
            
        if arr[i-1,col_loc] < 0 and arr[i,col_loc] < 0:
            counter += 1
        elif arr[i-1,col_loc] > 0 and arr[i,col_loc] > 0:
            counter += 1  
        else:
            counter = 0
            
        if counter == num:
            arr[i,-1] = 1
            counter = 0
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE OF TRIGGER DF:',df[df[col + '_consecutive_trigger'] == 1].shape)
    return df

def get_pearsons_corr(df,lookback = 10):
    print('GETTING PEARSONS CORR')
    df['ind'] = list(range(df.shape[0]))
    df['pearsons_corr'] = 0
    ind_col = df.columns.get_loc('ind')
    o_col = df.columns.get_loc('o')
    
    arr = df.values
    for i in range(arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        r, p = sp.stats.pearsonr(arr[(i - looback) : i,ind_col], arr[(i - looback) : i,o_col])
        arr[i,-1] = r
    return pd.DataFrame(arr,columns = df.columns)

def get_pearsons_corr(df,lookback = 10):
    print('GETTING PEARSONS CORR')
    df['ind'] = list(range(df.shape[0]))
    df['pearsons_corr'] = 0
    ind_col = df.columns.get_loc('ind')
    o_col = df.columns.get_loc('o')
    
    arr = df.values
    for i in range(lookback,arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        r, p = sp.stats.pearsonr(arr[(i - lookback) : i,ind_col], arr[(i - lookback) : i,o_col])
        arr[i,-1] = r
    return pd.DataFrame(arr,columns = df.columns)
def get_pearsons_corr2(df,lookback = 10):
    print('GETTING PEARSONS CORR')
    df['ind'] = list(range(df.shape[0]))
    df['pearsons_lookup'] = 0
    df['pearsons_corr2'] = 0
    ind_col = df.columns.get_loc('ind')
    o_col = df.columns.get_loc('o')
    c_col = df.columns.get_loc('c')
    new_col = df.columns.get_loc('pearsons_lookup')
    
    arr = df.values
    for i in range(lookback,arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        if i % 2 == 0:
            arr[i,new_col] = arr[i,o_col]
        else:
            arr[i,new_col] = arr[i,c_col]        
            
            
    for i in range(lookback,arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        r, p = sp.stats.pearsonr(arr[(i - lookback) : i,ind_col], arr[(i - lookback) : i,new_col])
        arr[i,-1] = r
    return pd.DataFrame(arr,columns = df.columns)
def convert_timestamp(df):
    time_col = df.columns.get_loc('time')
    arr = df.values 
    for i in range(arr.shape[0]):
        arr[i,time_col] = datetime.strptime(arr[i,time_col][:-4], '%Y-%m-%dT%H:%M:%S.%f')
    return pd.DataFrame(arr,columns = df.columns)
def get_best_fit(df,lookback = 10):

    def get_slope(y1,y2,total_x = 10):
        """y = mx + b"""
        return (y2 - y1) / total_x
    def get_best_fit_vals(y1,y2,total_x = 10):
        m = get_slope(y1,y2,total_x = total_x)
        lst = []
        for i in range(total_x):
            lst.append((m * i) + y1)
        return lst
    def compare_vals(lst,open_list,close_list,total_x):

        for i in range(total_x):
            if lst[i] <= max(open_list[i],close_list[i]) and lst[i] >= min(open_list[i],close_list[i]):
                pass
            else:
                return 0
        return 1
    print('GETTING BEST FIT INDICATOR')
    df['best_fit'] = 0
    o_col = df.columns.get_loc('o')
    c_col = df.columns.get_loc('c')
    new_col = df.columns.get_loc('best_fit')
    
    arr = df.values
    total_x = lookback 
    for i in range(lookback,arr.shape[0]):
        if i % 200000 == 0:
            print(i)

        y1 = np.mean([arr[i - total_x,o_col],arr[i - total_x,c_col]])
        y2 = np.mean([arr[i ,o_col],arr[i ,c_col]])
        
        temp_lst = get_best_fit_vals(y1,y2,total_x)
        arr[i,new_col] = compare_vals(lst = temp_lst,open_list = list(arr[i - total_x:i,o_col]),close_list = list(arr[i - total_x:i,c_col]),total_x = total_x)
            
    
    return pd.DataFrame(arr,columns = df.columns)   

def print_example(df,ind_list,ind = 30,delta = 240,trendline_lookback = 20):
    i = ind_list[ind]   
    print('row loc:',i,' ind:',ind,' delta:',delta)
    fig = go.Figure(data=go.Candlestick(x=df.iloc[i - delta:i + (delta*2),:]['time'],
                        open=df.iloc[i - delta:i + (delta*2),:]['o'],
                        high=df.iloc[i - delta:i + (delta*2),:]['h'],
                        low=df.iloc[i - delta:i + (delta*2),:]['l'],
                        close=df.iloc[i - delta:i + (delta*2),:]['c']))


    fig.add_vrect(x0=df['time'].iloc[i - 1], x1=df['time'].iloc[i+1], 
                  annotation_text="trigger point" , annotation_position="top left",
                  fillcolor="green", opacity=0.25, line_width=0)
    
    fig.add_shape(type='line',
                    x0=df.iloc[i - trendline_lookback,:]['time'],
                    y0=df.iloc[i - trendline_lookback,:]['o'],
                    x1=df.iloc[i,:]['time'],
                    y1=df.iloc[i ,:]['o'],
                    line=dict(color='Red',),
                    xref='x',
                    yref='y'
    )
    
    
    try:
        plot(fig)
    except:
        from plotly.offline import plot
        plot(fig)
def get_max_min_open_or_close(df):
    o_col = df.columns.get_loc('o')
    c_col = df.columns.get_loc('c')
    df['max_o_c'] = 0
    df['min_o_c'] = 0
    max_col = df.columns.get_loc('max_o_c')
    min_col = df.columns.get_loc('min_o_c')    
    arr = df.values
    for i in range(arr.shape[0]):
        arr[i,max_col] = max(arr[i,o_col],arr[i,c_col])
        arr[i,min_col] = min(arr[i,o_col],arr[i,c_col])
    return pd.DataFrame(arr,columns = df.columns)

def channel_indicator(df,lookback = 20):
    """Take the max of a bunch of consecutive candles and find the slope of the line
    Take the min of a bunch of consecutive candles and find the slope of the line
    
    """
    def get_slope(y1,y2,total_x = 10):
        """y = mx + b"""
        return (y2 - y1) / total_x
    def get_best_fit_vals(y1,y2,total_x = 10):
        m = get_slope(y1,y2,total_x = total_x)
        lst = []
        for i in range(total_x):
            lst.append((m * i) + y1)
        return lst
    def compare_vals(lst,check_list,total_x,check_type = 'max'):

        for i in range(total_x):
            if check_type == 'max':
                if lst[i] >= check_list[i]:
                    pass
                else:
                    return 0
            if check_type == 'min':
                if lst[i] <= check_list[i]:
                    pass
                else:
                    return 0
        return 1
    
    
    print('GETTING CHANNEL INDICATOR')
    df['channel_indicator'] = 0
    max_col = df.columns.get_loc('max_o_c')
    min_col = df.columns.get_loc('min_o_c')
    new_col = df.columns.get_loc('channel_indicator')
    df['spread_indicator'] = 0
    spread_col = df.columns.get_loc('spread_indicator')
    
    arr = df.values
    total_x = lookback 
    for i in range(lookback,arr.shape[0]):
        if i % 200000 == 0:
            print(i)

        y1 = arr[i - total_x,max_col]
        y2 = arr[i ,max_col]
        
        temp_lst1 = get_best_fit_vals(y1,y2,total_x)
        check_1 = compare_vals(lst = temp_lst1,
                                      check_list = list(arr[i - total_x:i,min_col]),
                                      total_x = total_x,
                                      check_type = 'max'
                                     )
        
        
        y1 = arr[i - total_x,min_col]
        y2 = arr[i ,min_col]
        
        temp_lst2 = get_best_fit_vals(y1,y2,total_x)
        check_2 = compare_vals(lst = temp_lst2,
                                      check_list = list(arr[i - total_x:i,max_col]),
                                      total_x = total_x,
                                      check_type = 'min'
                                     )   
        spread = np.array(temp_lst1) - np.array(temp_lst2)     
        arr[i,spread_col] = max(spread)
        
        
        if check_1 == 1 and check_2 == 1:
            arr[i,new_col] = 1
    
    return pd.DataFrame(arr,columns = df.columns)  


def get_support(df,lookup_range = 60,stop_range = 20000,lookup_range2 = 200):
    print('GETTING SUPPORT INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    l_col = df.columns.get_loc('l')
    df['support_lookup'] = 0
    df['support_indicator'] = 0
    lookup_col = df.columns.get_loc('support_lookup')
    new_col = df.columns.get_loc('support_indicator')
    arr = df.values
    
    for i in range(arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            if arr[i,c_col] == min(arr[i - lookup_range : i + lookup_range,c_col]):
                lookup_ind = i
                val = arr[i,c_col]
                lookup_check = 0
                for j in range(i + lookup_range2,i + stop_range):
                    if arr[j,l_col] <= val and lookup_check == 0:
                        arr[j,new_col] = 1
                        arr[j,lookup_col] = lookup_ind
                        lookup_check = 1
                        break
        except:
            pass
        

    e = time.time()
    print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['support_indicator'] == 1].shape)
    return df
def simulate_results(
    num_trades = 200,
    acc_val = 10000,
    rr = 6,
    risk_size = .02,
    win_rate = .2,
pr = True):
    start = acc_val
    for i in range(num_trades):
        rand = random()
        if rand > win_rate:
            acc_val = acc_val - (acc_val * risk_size)
        else:
            acc_val = acc_val + (acc_val * (risk_size * rr))
    if pr:
        print('STARTING VAL:',round(start),' ENDING VAL:',round(acc_val))
    return round(acc_val)


def strategy_tester_buy(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING BUY SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            try:
                for j in range(i + 1,i + 10000):
                    if i not in trade_list:
                        if arr[j,l_col] < val - sl:
                            trade_res.append(-10)
                            trade_list.append(i)
                            losses.append(i)
                            break
                        if arr[j,h_col] >= val + tp:
                            trade_res.append(50)
                            trade_list.append(i)
                            wins.append(i)
                            break
            except:
                pass
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
   # num_trades = len(trade_list)
  #  print('WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    vals = []


    acc_val = 10000



    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate


def strategy_tester_sell(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING SELL SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            for j in range(i + 1,i + 10000):
                if i not in trade_list:
                    if arr[j,h_col] > val + sl:
                        trade_res.append(-10)
                        trade_list.append(i)
                        losses.append(i)
                        break
                    if arr[j,l_col] <= val - tp:
                        trade_res.append(50)
                        trade_list.append(i)
                        wins.append(i)
                        break
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
   # num_trades = len(trade_list)
  #  print('WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    vals = []


    acc_val = 10000



    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate

def strategy_tester_buy(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING BUY SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            trade_id = 0
            try:
                for j in range(i + 1,i + 10000):
                    if i not in trade_list:
                        if trade_id == 0:
                            if arr[j,l_col] < val - sl:
                                trade_res.append(-10)
                                trade_list.append(i)
                                losses.append(i)
                                trade_id = 1

                                break
                            if arr[j,h_col] >= val + tp:
                                trade_res.append(50)
                                trade_list.append(i)
                                wins.append(i)
                                trade_id = 1
                                break
            except:
                pass
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
   # num_trades = len(trade_list)
  #  print('WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    vals = []


    acc_val = 10000



    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate,wins,losses

def strategy_tester_sell(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING SELL SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            try:
                for j in range(i + 1,i + 10000):
                    if i not in trade_list:
                        if arr[j,h_col] > val + sl:
                            trade_res.append(-10)
                            trade_list.append(i)
                            losses.append(i)
                            break
                        if arr[j,l_col] <= val - tp:
                            trade_res.append(50)
                            trade_list.append(i)
                            wins.append(i)
                            break
            except:
                pass
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
   # num_trades = len(trade_list)
  #  print('WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    vals = []


    acc_val = 10000



    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate,wins,losses
def ema(df,num = 14):
    print('GETTING EMA INDICATOR FOR:',num)
    close_col = df.columns.get_loc('c')
    df['ema_' + str(num)] = df['c']
    arr = df.values
    mult = 2/ (num + 1)
    for i in range(num,arr.shape[0]):
        sma = sum(arr[i - num + 1: i + 1,close_col]) / num
        arr[i,-1] = ((arr[i,close_col] - arr[i - 1,-1]) * mult) + arr[i - 1,-1]
    return pd.DataFrame(arr,columns = df.columns)
def strategy_tester_buy(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING BUY SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            trade_id = 0
            try:
                for j in range(i + 1,i + 10000):
                    if i not in trade_list:
                        if trade_id == 0:
                            if arr[j,l_col] < val - sl:
                                trade_res.append(-10)
                                trade_list.append(i)
                                losses.append(i)
                                trade_id = 1

                                break
                            if arr[j,h_col] >= val + tp:
                                trade_res.append(50)
                                trade_list.append(i)
                                wins.append(i)
                                trade_id = 1
                                break
            except:
                pass
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
   # num_trades = len(trade_list)
  #  print('WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    vals = []


    acc_val = 10000



    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate,wins,losses

def strategy_tester_sell(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING SELL SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            try:
                for j in range(i + 1,i + 10000):
                    if i not in trade_list:
                        if arr[j,h_col] > val + sl:
                            trade_res.append(-10)
                            trade_list.append(i)
                            losses.append(i)
                            break
                        if arr[j,l_col] <= val - tp:
                            trade_res.append(50)
                            trade_list.append(i)
                            wins.append(i)
                            break
            except:
                pass
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
   # num_trades = len(trade_list)
  #  print('WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    vals = []


    acc_val = 10000



    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate,wins,losses
file = 'XAU_USD_M1_2019-01-01_2022-01-31.csv'
#file = 'GBP_JPY_M1_2019-01-01_2022-01-31.csv'
#file = 'XAU_USD_S5/2020-08-01_2020-09-01.csv'
#file = 'GBP_JPY_S5/2020-08-01_2020-09-01.csv'

file = 'EUR_USD_M1_2019-01-01_2022-01-31.csv'
file = 'GBP_JPY_M1_2019-01-01_2022-01-31.csv'
file = 'EUR_USD_M1_2019-01-01_2022-01-31.csv'
file = 'GBP_JPY_M1_2019-01-01_2022-01-31.csv'

file = 'EUR_USD_M1_2019-01-01_2022-01-31.csv'


def add_delta_cols(df):
    #df['delta_vector'] = 0
    #df['delta_max_vector'] = 0

    df['delta_vector'] = 0
    df['delta_max'] = 0
    df['upper_wick'] = 0
    df['lower_wick'] = 0
    
    dv_col = df.columns.get_loc('delta_vector')
    dm_col = df.columns.get_loc('delta_max')
    uw_col = df.columns.get_loc('upper_wick')
    lw_col = df.columns.get_loc('lower_wick')
    
    o_col = df.columns.get_loc('o')
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    arr = df.values
    for i in range(arr.shape[0]):
        arr[i,dv_col] = arr[i,c_col] - arr[i,o_col]
        arr[i,dm_col] = arr[i,h_col] - arr[i,l_col]
        if arr[i,c_col] > arr[i,o_col]:
            arr[i,uw_col] = arr[i,h_col] - arr[i,c_col]
            arr[i,lw_col] = arr[i,o_col] - arr[i,l_col]
            
        elif arr[i,c_col] < arr[i,o_col]:
            arr[i,uw_col] = arr[i,h_col] - arr[i,o_col]
            arr[i,lw_col] = arr[i,c_col] - arr[i,l_col]   
            
    df = pd.DataFrame(arr,columns = df.columns)
    df['delta'] = abs(df['delta_vector'])
    
    return df
def load_df(pair = 'EUR_USD'
            ,granularity = 'M5'
            ,start = datetime(2016,1,1,0,0,0)
            ,end = datetime(2022,7,31,0,0,0)):
    dir_name = os.getcwd() + '/' + pair + '_' + granularity
    path = dir_name + '/' + str(date(start.year,start.month,start.day)) + '_' + str(date(end.year,end.month,end.day)) + '.csv'
    print('PATH:',path)
    df = pd.read_csv(path)
    df = add_delta_cols(df)
    print(df.shape)
    return df

def simulate_results(
    num_trades = 200,
    acc_val = 10000,
    rr = 6,
    risk_size = .02,
    win_rate = .2,
    pr = True):
    
    start = acc_val
    for i in range(num_trades):
        rand = random.random()
        if rand > win_rate:
            acc_val = acc_val - (acc_val * risk_size)
        else:
            acc_val = acc_val + (acc_val * (risk_size * rr))
    if pr:
        print('STARTING VAL:',round(start),' ENDING VAL:',round(acc_val))
    return round(acc_val)

pair = 'GBP_JPY'
pair = 'EUR_USD'
pair = 'GBP_USD'
granularity = 'M5'
#df = load_df(pair = pair,granularity = granularity,start = datetime(2016,1,1,0,0,0),end = datetime(2022,7,31,0,0,0))
#df_ = df.copy()
#granularity2 = 'M1'
#df2 = load_df(pair = pair,granularity = granularity2,start = datetime(2016,1,1,0,0,0),end = datetime(2022,7,31,0,0,0))
#df2.head()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # FINAL SIM

# %%
def run_single_parameter_sim_loop(df,
                                 df_,
                                  pair,
                                 lookup_range,
                                    lookup_range2,
                                    stop_range,
                                    pip_threshold,
                                    support_low,
                                   bullish_ma,
                                    bullish_candle,
                                    candle_size,
                                    touch_low,
                                    midpoint_offset,
                                    bound_pips,sls,tps):
    
    def strategy_tester_buy(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):

        col_num = df.columns.get_loc(col)
        h_col = df.columns.get_loc('h')
        l_col = df.columns.get_loc('l')
        c_col = df.columns.get_loc('c')
        entry_col = df.columns.get_loc(entry)
        arr = df.values
        temp_df = df[df[col] == 1]
 
        trade_list = []
        trade_res = []
        wins = []
        losses = []
        for i in range(arr.shape[0]):

            if arr[i,col_num] == 1:
                val = arr[i,entry_col]
                trade_id = 0
                try:
                    for j in range(i + 1,i + 20000):
                        if i not in trade_list:
                            if trade_id == 0:
                                if arr[j,l_col] <= val - sl:
                                    trade_res.append(-10)
                                    trade_list.append(i)
                                    losses.append(i)
                                    trade_id = 1

                                    break
                                elif arr[j,h_col] >= val + tp:
                                    trade_res.append(50)
                                    trade_list.append(i)
                                    wins.append(i)
                                    trade_id = 1
                                    break
                except:
                    pass
        win_rate = len(wins) / len(trade_list)
        rr = tp / sl
        vals = []


        acc_val = 10000

        for i in range(30):

            final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
            vals.append(final_val)


        #print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
        return np.median(vals),win_rate,wins,losses

    def strategy_tester_sell(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):

        col_num = df.columns.get_loc(col)
        h_col = df.columns.get_loc('h')
        l_col = df.columns.get_loc('l')
        c_col = df.columns.get_loc('c')
        entry_col = df.columns.get_loc(entry)
        arr = df.values
        temp_df = df[df[col] == 1]
   
        trade_list = []
        trade_res = []
        wins = []
        losses = []
        for i in range(arr.shape[0]):

            if arr[i,col_num] == 1:
                val = arr[i,entry_col]
                try:
                    for j in range(i + 1,i + 20000):
                        if i not in trade_list:
                            if arr[j,h_col] >= val + sl:
                                trade_res.append(-10)
                                trade_list.append(i)
                                losses.append(i)
                                break
                            elif arr[j,l_col] <= val - tp:
                                trade_res.append(50)
                                trade_list.append(i)
                                wins.append(i)
                                break
                except:
                    pass
        win_rate = len(wins) / len(trade_list)
        rr = tp / sl
        vals = []

        acc_val = 10000

        for i in range(30):

            final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
            vals.append(final_val)


        #print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
        return np.median(vals),win_rate,wins,losses
    
    
    def get_support(df,
                    lookup_range = 1500,
                    lookup_range2 = 2400,
                    stop_range = 2200,
                    pip_threshold = .005,
                    support_low = True,
                   bullish_ma = True,
                    bullish_candle = True,
                    candle_size = .001,
                    touch_low = True,
                    midpoint_offset = 0,
                    bound_pips = .001
                   ):
        print('GETTING SUPPORT INDICATOR')
        s = time.time()
        c_col = df.columns.get_loc('c')
        o_col = df.columns.get_loc('o')
        l_col = df.columns.get_loc('l')
        h_col = df.columns.get_loc('h')
        uw_col = df.columns.get_loc('upper_wick')
        lw_col = df.columns.get_loc('lower_wick')
        dv_col = df.columns.get_loc('delta_vector')
        dm_col = df.columns.get_loc('delta_max')
        d_col = df.columns.get_loc('delta')
        ma1_col = df.columns.get_loc('smma_21')
        ma2_col = df.columns.get_loc('smma_50')
        ma3_col = df.columns.get_loc('smma_200')    

        df['support_lookup'] = 0
        df['support_indicator'] = 0

        lookup_col = df.columns.get_loc('support_lookup')
        new_col = df.columns.get_loc('support_indicator')

        if support_low:
            reversal_col = df.columns.get_loc('l')
        else:
            reversal_col = df.columns.get_loc('c')

        if touch_low:
            touch_col = df.columns.get_loc('l')
        else:
            touch_col = df.columns.get_loc('c')    

        arr = df.values
        min_count = 0

        print('STOP RANGE:',stop_range)
        c = 0 

    #['time', 'volume', 'o', 'h', 'l', 'c', 'utc_timestamp', 'est_timestamp',
     #      'smma_21', 'smma_50', 'smma_200', 'ema_42', 'ema_150', 'ema_600',
      #     'bearish_engulfing', 'bullish_engulfing', 'bearish_tls', 'bullish_tls',
       #    'new_york', 'london', 'delta_vector', 'delta_max', 'upper_wick',
        #   'lower_wick', 'delta']

        for i in range(arr.shape[0]):
           # if i % 200000 == 0:
            #    print(i)
            try:
                #DEFINE SUPPORT/RESISTANCE as the MIN or MAX of a lookup range
                min_ = min(arr[i - lookup_range : i + lookup_range2,reversal_col])

                # If the current val is at that reversal point:
                # Check and make sure we have an adequate movement off of that reversal point
                # this is defined by the pip_range and pip threshold, pip threshold is a user defined parameter
                if arr[i,reversal_col] == min_:
                    lookup_ind = i
                    val = arr[i,reversal_col]
                    lookup_check = 0
                    max_ = max(arr[i : i + lookup_range2,c_col])
                    pip_range = max_ - min_
                    c = c + 1
                    if pip_threshold <= pip_range:
                        # Now that all of these conditions are met
                        # We need to look into the future to see if we hit this reversal level, this is defined by the stop range
                        for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                            #If all of the following conditions are met, we will mark the array with a 1 signal to indicated we would place a trade                       
                            #CANDLE BULL OR BEAR
                            if arr[j,c_col] >= arr[j,o_col]:
                                bull = True
                            else:
                                bull = False
                            #MOVING AVG INDICATOR
                            if bullish_ma == True:
                                if arr[j,ma1_col] > arr[j,ma2_col] and arr[j,ma2_col] > arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0
                            elif bullish_ma == False:
                                if arr[j,ma1_col] < arr[j,ma2_col] and arr[j,ma2_col] < arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0                        
                            else:
                                ma_indicator = 1

                            midpoint = val + midpoint_offset
                            lower_bound = midpoint - bound_pips
                            upper_bound = midpoint + bound_pips

                            if lookup_check == 0 and \
                            ma_indicator == 1 and\
                            (bull == bullish_candle or bullish_candle == None) and\
                            arr[j,d_col] >= candle_size and\
                            (arr[j,touch_col] >= lower_bound and arr[j,touch_col] <= upper_bound):

                                arr[j,new_col] = 1
                                arr[j,lookup_col] = lookup_ind
                                lookup_check = 1
                                break

            except:
                pass

        print('COUNT:',c)

        e = time.time()
        print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
        df = pd.DataFrame(arr,columns = df.columns)
        print('SHAPE',df[df['support_indicator'] == 1].shape)
        return df


    def get_resistance(df,
                    lookup_range = 1500,
                    lookup_range2 = 2400,
                    stop_range = 2200,
                    pip_threshold = .005,
                    support_low = True,
                   bullish_ma = True,
                    bullish_candle = True,
                    candle_size = .001,
                    touch_low = True,
                    midpoint_offset = 0,
                    bound_pips = .001
                   ):
        print('GETTING RESISTANCE INDICATOR')
        s = time.time()
        c_col = df.columns.get_loc('c')
        o_col = df.columns.get_loc('o')
        l_col = df.columns.get_loc('l')
        h_col = df.columns.get_loc('h')
        uw_col = df.columns.get_loc('upper_wick')
        lw_col = df.columns.get_loc('lower_wick')
        dv_col = df.columns.get_loc('delta_vector')
        dm_col = df.columns.get_loc('delta_max')
        d_col = df.columns.get_loc('delta')
        ma1_col = df.columns.get_loc('smma_21')
        ma2_col = df.columns.get_loc('smma_50')
        ma3_col = df.columns.get_loc('smma_200')    

        df['resistance_lookup'] = 0
        df['resistance_indicator'] = 0

        lookup_col = df.columns.get_loc('resistance_lookup')
        new_col = df.columns.get_loc('resistance_indicator')

        if support_low:
            reversal_col = df.columns.get_loc('h')
        else:
            reversal_col = df.columns.get_loc('c')

        if touch_low:
            touch_col = df.columns.get_loc('h')
        else:
            touch_col = df.columns.get_loc('c')    

        arr = df.values
        min_count = 0
        c = 0
        for i in range(arr.shape[0]):

            try:
                #DEFINE SUPPORT/RESISTANCE as the MIN or MAX of a lookup range
                max_ = max(arr[i - lookup_range : i + lookup_range2,reversal_col])

                # If the current val is at that reversal point:
                # Check and make sure we have an adequate movement off of that reversal point
                # this is defined by the pip_range and pip threshold, pip threshold is a user defined parameter
                if arr[i,reversal_col] == max_:
                    lookup_ind = i
                    val = arr[i,reversal_col]
                    lookup_check = 0
                    min_ = min(arr[i : i + lookup_range2,c_col])
                    pip_range = max_ - min_
                    c = c + 1
                    if pip_threshold <= pip_range:
                        # Now that all of these conditions are met
                        # We need to look into the future to see if we hit this reversal level, this is defined by the stop range
                        for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                            #If all of the following conditions are met, we will mark the array with a 1 signal to indicated we would place a trade                       
                            #CANDLE BULL OR BEAR
                            if arr[j,c_col] >= arr[j,o_col]:
                                bull = True
                            else:
                                bull = False
                            #MOVING AVG INDICATOR
                            if bullish_ma == True:
                                if arr[j,ma1_col] > arr[j,ma2_col] and arr[j,ma2_col] > arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0
                            elif bullish_ma == False:
                                if arr[j,ma1_col] < arr[j,ma2_col] and arr[j,ma2_col] < arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0                        
                            else:
                                ma_indicator = 1

                            midpoint = val + midpoint_offset
                            lower_bound = midpoint - bound_pips
                            upper_bound = midpoint + bound_pips

                            if lookup_check == 0 and \
                            ma_indicator == 1 and\
                            (bull == bullish_candle or bullish_candle == None) and\
                            arr[j,d_col] >= candle_size and\
                            (arr[j,touch_col] >= lower_bound and arr[j,touch_col] <= upper_bound):

                                arr[j,new_col] = 1
                                arr[j,lookup_col] = lookup_ind
                                lookup_check = 1
                                break

            except:
                pass

        e = time.time()
        df = pd.DataFrame(arr,columns = df.columns)
        print('SHAPE',df[df['resistance_indicator'] == 1].shape)
        return df

    s = time.time()
    print('RUNNING SINGLE PARAMETER LOOP FOR PARAMS:',
          'lookup_range',lookup_range,
          'lookup_range2', lookup_range2,
                    'stop_range', stop_range,
                    'pip_threshold' , pip_threshold,
                    'support_low' , support_low,
                   'bullish_ma' , bullish_ma,
                    'bullish_candle' , bullish_candle,
                    'candle_size' , candle_size,
                    'touch_low' , touch_low,
                    'midpoint_offset' , midpoint_offset,
                    'bound_pips' , bound_pips)
    
    cols = [
        'instrument'
        ,'timeframe'
        ,'buy_or_sell'
        ,'trade_strategy'
       ,'median_sim_ending_val'
        ,'median_sim_ending_val2'
        ,'total_sim_val'
        ,'starting_val'
        ,'sl'
        ,'tp'
        ,'RR'
        ,'win_rate'    
        ,'num_trades'
        ,'risk_size' 
        ,'actual_number_of_trades'   
        ,'buy_or_sell2'
        ,'trade_strategy2'

        ,'win_rate2'    
        ,'actual_number_of_trades2'    
        ,'lookup_range' 
        ,'lookup_range2' 
        ,'stop_range' 
        ,'pip_threshold' 
        ,'support_low' 
        ,'bullish_ma' 
        ,'bullish_candle'
        ,'candle_size' 
        ,'touch_low' 
        ,'midpoint_offset' 
        ,'bound_pips' 

    ]

    df = get_support(df,
                    lookup_range = lookup_range,
                    lookup_range2 = lookup_range2,
                    stop_range = stop_range,
                    pip_threshold = pip_threshold,
                    support_low = support_low,
                   bullish_ma = bullish_ma,
                    bullish_candle = bullish_candle,
                    candle_size = candle_size,
                    touch_low = touch_low,
                    midpoint_offset = midpoint_offset,
                    bound_pips = bound_pips
                   )

    if bullish_ma == True:
        res_bullish_ma = False
    elif bullish_ma == False:
        res_bullish_ma = True
    else:
        res_bullish_ma = None

    if bullish_candle == True:
        res_bullish_candle = False
    elif bullish_candle == False:
        res_bullish_candle = True
    else:
        res_bullish_candle = None

    res_midpoint_offset = midpoint_offset * -1

    df_ = get_resistance(df_,
                    lookup_range = lookup_range,
                    lookup_range2 = lookup_range2,
                    stop_range = stop_range,
                    pip_threshold = pip_threshold,
                    support_low = support_low,
                   bullish_ma = res_bullish_ma,
                    bullish_candle = res_bullish_candle,
                    candle_size = candle_size,
                    touch_low = touch_low,
                    midpoint_offset = res_midpoint_offset,
                    bound_pips = bound_pips
                   )

    trade_strategy = 'support_indicator'
    trade_strategy2 = 'resistance_indicator'

    #trade_strategy = 'resistance_indicatorc'
    num_trades = 400
    risk_size = .01

    starting_val = 10000
    instrument = pair
    timeframe = 'M5'
    temp_lst = []
    actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
    actual_number_of_trades2 = df_[df_[trade_strategy2] == 1].shape[0]
    for sl in sls:
        for tp in tps:
            ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)
            ending_val2,win_rate2,wins2,losses2 = strategy_tester_sell(df_,col = trade_strategy2,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

            lst = [instrument,
                    timeframe,
                    'buy',
                    trade_strategy,
                    ending_val,
                    ending_val2,
                   ending_val + ending_val2 - starting_val,
                    starting_val,
                    sl,
                    tp,
                    round(tp / sl,4),
                    round(win_rate,4),
                    num_trades,
                    risk_size,
                    actual_number_of_trades,
                   'sell',
                    trade_strategy2,

                    win_rate2,
                    actual_number_of_trades2,
                    lookup_range,
                    lookup_range2,
                    stop_range,
                    pip_threshold,
                    support_low ,
                    bullish_ma ,
                    bullish_candle ,
                    candle_size ,
                    touch_low ,
                    midpoint_offset,
                    bound_pips 
            ]

            temp_lst.append(lst)


            ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)
            ending_val2,win_rate2,wins2,losses2 = strategy_tester_buy(df_,col = trade_strategy2,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

            lst = [instrument,
                    timeframe,
                    'sell',
                    trade_strategy,
                    ending_val,
                    ending_val2,
                   ending_val + ending_val2 - starting_val,
                    starting_val,
                    sl,
                    tp,
                    round(tp / sl,4),
                    round(win_rate,4),
                    num_trades,
                    risk_size,
                    actual_number_of_trades,
                   'buy',
                    trade_strategy2,
                    win_rate2,
                    actual_number_of_trades2,
                    lookup_range,
                    lookup_range2,
                    stop_range,
                    pip_threshold,
                    support_low ,
                    bullish_ma ,
                    bullish_candle ,
                    candle_size ,
                    touch_low ,
                    midpoint_offset,
                    bound_pips 
            ]

            temp_lst.append(lst)




    final_df = pd.DataFrame(temp_lst,columns = cols)
    final_df = final_df.sort_values(by = 'total_sim_val',ascending = False)
    
    support_best = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
    resistance_best = final_df.sort_values(by = 'median_sim_ending_val2',ascending = False)
    overall_best = final_df.sort_values(by = 'total_sim_val',ascending = False)

    print('SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',support_best['buy_or_sell'].iloc[0],'/',support_best['median_sim_ending_val'].iloc[0],'/',support_best['win_rate'].iloc[0],'/',support_best['RR'].iloc[0],'/',support_best['tp'].iloc[0],'/',support_best['sl'].iloc[0],'/',support_best['actual_number_of_trades'].iloc[0]
         )
    print('RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',resistance_best['buy_or_sell'].iloc[0],'/',resistance_best['median_sim_ending_val2'].iloc[0],'/',resistance_best['win_rate2'].iloc[0],'/',resistance_best['RR'].iloc[0],'/',resistance_best['tp'].iloc[0],'/',resistance_best['sl'].iloc[0],'/',resistance_best['actual_number_of_trades2'].iloc[0]
         )
    print('OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',overall_best['buy_or_sell'].iloc[0],'/',overall_best['total_sim_val'].iloc[0],'/',overall_best['win_rate'].iloc[0],'/',overall_best['RR'].iloc[0],'/',overall_best['tp'].iloc[0],'/',overall_best['sl'].iloc[0],'/',overall_best['actual_number_of_trades'].iloc[0]
         )


    e = time.time()
    print('TOTAL PARAM SIM LOOP TIME:',round((e-s)/60,2),'MINUTES')
    return final_df


def generate_random_param_list():
    def return_random_list_element(lst):
        return lst[random.randint(0,len(lst) - 1)]
    # param loop
    # PARAM DEFINITON
    if 'JPY' in pair:
        pip_thresholds = [.3,.5,.7]
        sls = [.05,.075,.1,.125,.15,.2,.25]
        tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
        candle_sizes = [.05,.075,.1,.15]
        midpoint_offsets = [0,-.05,.05,-.1,.1,-.15,.15,-.25,.25]
        bound_pips_ = [.025,.05,.075,.1,.15]
    else:
        pip_thresholds = [.003,.005,.007]
        sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
        tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
        candle_sizes = [.0005,.00075,.001,.0015]
        midpoint_offsets = [0,-.0005,.0005,-.001,.001,-.0015,.0015,-.0025,.0025]
        bound_pips_ = [.00025,.0005,.00075,.001,.0015]

    lookup_ranges = [100,288,400,600]
    lookup_ranges2 = [100,288,400,600]    
    stop_ranges = [1000,3000,6000,8000]

    support_lows = [True,False]
    bullish_mas = [True,False,None]
    bullish_candles = [True,False,None]
    touch_lows = [True,False]
    
    lookup_range = return_random_list_element(lookup_ranges)
    lookup_range2 = return_random_list_element(lookup_ranges2)
    stop_range = return_random_list_element(stop_ranges)
    pip_threshold = return_random_list_element(pip_thresholds)
    support_low = return_random_list_element(support_lows)
    bullish_ma = return_random_list_element(bullish_mas)
    bullish_candle = return_random_list_element(bullish_candles)
    candle_size = return_random_list_element(candle_sizes)
    touch_low = return_random_list_element(touch_lows)
    midpoint_offset = return_random_list_element(midpoint_offsets)
    bound_pips = return_random_list_element(bound_pips_)
    param_check_list = [lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips]
    
    return param_check_list,lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips,sls,tps



def run_sim(pair,max_loops):
    print('RUNNING SIM...')
    file = pair + '_M1_2019-01-01_2022-01-31.csv'
    df = load_df(pair = pair,granularity ='M5',start = datetime(2016,1,1,0,0,0),end = datetime(2022,7,31,0,0,0))
    df_ = df.copy()
    file_name = 'SIM_CLEAN_' + file
    file_name2 = 'CHECK_PARAMS_' + file
    print(file_name,file_name2)
    try:
        final_df = pd.read_csv(file_name)
        loop_number = final_df['loop_number'].max()

        param_check_df = pd.read_csv(file_name2)
        param_check_lists = param_check_df.values.tolist()

    except:
        final_df = pd.DataFrame([0])
        param_check_df = pd.DataFrame([0])
        loop_number = 0
        param_check_lists = []
    
    while max_loops >= loop_number:
        checker = 0
        while checker == 0:
            param_check_list,lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips,sls,tps = generate_random_param_list()
            if param_check_list not in param_check_lists:
                param_check_lists.append(param_check_list)

                checker = 1
        try:
            if final_df.shape[0] == 1:
                loop_number = 1
            else:
                loop_number = final_df['loop_number'].max() + 1

            print('LOOP NUMBER:',loop_number)
            loop_df = run_single_parameter_sim_loop(df,
                                                 df_,
                                                  pair,
                                                 lookup_range,
                                                    lookup_range2,
                                                    stop_range,
                                                    pip_threshold,
                                                    support_low,
                                                   bullish_ma,
                                                    bullish_candle,
                                                    candle_size,
                                                    touch_low,
                                                    midpoint_offset,
                                                    bound_pips,sls,tps)
            loop_df['loop_number'] = loop_number

            if final_df.shape[0] == 1:
                final_df = loop_df

            else:
                final_df = final_df.append(loop_df)

            final_df.to_csv(file_name,index = False)
            param_check_df = pd.DataFrame(param_check_lists)
            param_check_df.to_csv(file_name2,index = False)
       
        except:
            print('ERROR WITH THESE PARAMETERS... SKIPPING')

        support_best = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
        resistance_best = final_df.sort_values(by = 'median_sim_ending_val2',ascending = False)
        overall_best = final_df.sort_values(by = 'total_sim_val',ascending = False)

        print('OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',support_best['buy_or_sell'].iloc[0],'/',support_best['median_sim_ending_val'].iloc[0],'/',support_best['win_rate'].iloc[0],'/',support_best['RR'].iloc[0],'/',support_best['tp'].iloc[0],'/',support_best['sl'].iloc[0],'/',support_best['actual_number_of_trades'].iloc[0]
             )
        print('OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',resistance_best['buy_or_sell'].iloc[0],'/',resistance_best['median_sim_ending_val2'].iloc[0],'/',resistance_best['win_rate2'].iloc[0],'/',resistance_best['RR'].iloc[0],'/',resistance_best['tp'].iloc[0],'/',resistance_best['sl'].iloc[0],'/',resistance_best['actual_number_of_trades2'].iloc[0]
             )
        print('OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',overall_best['buy_or_sell'].iloc[0],'/',overall_best['total_sim_val'].iloc[0],'/',overall_best['win_rate'].iloc[0],'/',overall_best['RR'].iloc[0],'/',overall_best['tp'].iloc[0],'/',overall_best['sl'].iloc[0],'/',overall_best['actual_number_of_trades'].iloc[0]
             )
        print()
        print()
        print()
        
pair = 'GBP_USD'
run_sim(pair = pair,max_loops = 2500)
# Out:
# RUNNING SIM...
# PATH: /Users/aidanmcconnell/Documents/MARKET_ANALYTICS/forex/Macro/GBP_USD_M5/2016-01-01_2022-07-31.csv
# (489547, 25)
# SIM_CLEAN_GBP_USD_M1_2019-01-01_2022-01-31.csv CHECK_PARAMS_GBP_USD_M1_2019-01-01_2022-01-31.csv
# LOOP NUMBER: 830
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 400 stop_range 1000 pip_threshold 0.005 support_low False bullish_ma None bullish_candle None candle_size 0.00075 touch_low False midpoint_offset 0.0005 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 424
# TOTAL FUNCTION TIME: 0.3003516674041748  MINUTES
# SHAPE (208, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (203, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 74117.5 / 0.1875 / 7.0 / 0.007 / 0.001 / 208
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 84597.0 / 0.15763546798029557 / 9.3333 / 0.007 / 0.00075 / 203
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 83220.0 / 0.0962 / 9.3333 / 0.007 / 0.00075 / 208
# TOTAL PARAM SIM LOOP TIME: 1.71 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 831
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 600 stop_range 8000 pip_threshold 0.005 support_low True bullish_ma False bullish_candle True candle_size 0.0005 touch_low False midpoint_offset 0.0025 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 721
# TOTAL FUNCTION TIME: 0.3714176853497823  MINUTES
# SHAPE (408, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (382, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 26305.0 / 0.1789 / 6.0 / 0.003 / 0.0005 / 408
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 65564.0 / 0.1518324607329843 / 8.8 / 0.011 / 0.00125 / 382
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 70675.0 / 0.0907 / 11.0 / 0.011 / 0.001 / 408
# TOTAL PARAM SIM LOOP TIME: 1.8 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 832
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 288 stop_range 8000 pip_threshold 0.003 support_low False bullish_ma True bullish_candle False candle_size 0.001 touch_low False midpoint_offset -0.0015 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 499
# TOTAL FUNCTION TIME: 0.23395626544952391  MINUTES
# SHAPE (81, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (80, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 3533680.0 / 0.0988 / 26.0 / 0.013 / 0.0005 / 81
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 852688.5 / 0.1 / 22.0 / 0.011 / 0.0005 / 80
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 3631504.0 / 0.0988 / 26.0 / 0.013 / 0.0005 / 81
# TOTAL PARAM SIM LOOP TIME: 0.95 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 833
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 600 stop_range 1000 pip_threshold 0.007 support_low True bullish_ma False bullish_candle None candle_size 0.00075 touch_low False midpoint_offset -0.0005 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 263
# TOTAL FUNCTION TIME: 0.2440454324086507  MINUTES
# SHAPE (93, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (96, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 144951.0 / 0.4301 / 3.0 / 0.0015 / 0.0005 / 93
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 414816.5 / 0.1875 / 10.0 / 0.005 / 0.0005 / 96
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 407749.0 / 0.0645 / 10.0 / 0.005 / 0.0005 / 93
# TOTAL PARAM SIM LOOP TIME: 0.9 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 834
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 400 stop_range 3000 pip_threshold 0.003 support_low False bullish_ma False bullish_candle False candle_size 0.001 touch_low True midpoint_offset -0.0015 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 336
# TOTAL FUNCTION TIME: 0.17411869764328003  MINUTES
# SHAPE (82, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (59, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 66655.0 / 0.1585 / 8.6667 / 0.013 / 0.0015 / 82
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 130097.5 / 0.06779661016949153 / 22.0 / 0.011 / 0.0005 / 59
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 123441.5 / 0.0366 / 22.0 / 0.011 / 0.0005 / 82
# TOTAL PARAM SIM LOOP TIME: 0.74 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 835
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 400 stop_range 6000 pip_threshold 0.003 support_low False bullish_ma False bullish_candle True candle_size 0.0005 touch_low True midpoint_offset -0.0025 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 336
# TOTAL FUNCTION TIME: 0.17347113688786825  MINUTES
# SHAPE (212, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (197, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 239238.0 / 0.1226 / 14.0 / 0.007 / 0.0005 / 212
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 29153.5 / 0.2131979695431472 / 5.0 / 0.0025 / 0.0005 / 197
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 236270.0 / 0.1226 / 14.0 / 0.007 / 0.0005 / 212
# TOTAL PARAM SIM LOOP TIME: 0.81 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 836
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 400 stop_range 6000 pip_threshold 0.007 support_low True bullish_ma False bullish_candle False candle_size 0.0005 touch_low True midpoint_offset 0.001 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 495
# TOTAL FUNCTION TIME: 0.1326030651728312  MINUTES
# SHAPE (321, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (314, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 31687.0 / 0.2586 / 4.0 / 0.005 / 0.00125 / 321
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 24767.0 / 0.07006369426751592 / 17.3333 / 0.013 / 0.00075 / 314
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 31399.0 / 0.2586 / 4.0 / 0.005 / 0.00125 / 321
# TOTAL PARAM SIM LOOP TIME: 0.82 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 837
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 8000 pip_threshold 0.003 support_low False bullish_ma None bullish_candle None candle_size 0.0015 touch_low True midpoint_offset -0.0025 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 820
# TOTAL FUNCTION TIME: 0.11583589712778727  MINUTES
# SHAPE (317, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (311, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 68299.5 / 0.1325 / 10.4 / 0.013 / 0.00125 / 317
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 41688.0 / 0.17684887459807075 / 6.6667 / 0.005 / 0.00075 / 311
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 75761.5 / 0.1325 / 10.4 / 0.013 / 0.00125 / 317
# TOTAL PARAM SIM LOOP TIME: 0.81 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 838
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 600 stop_range 3000 pip_threshold 0.007 support_low True bullish_ma False bullish_candle True candle_size 0.001 touch_low True midpoint_offset -0.0015 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 263
# TOTAL FUNCTION TIME: 0.19938811858495076  MINUTES
# SHAPE (96, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (87, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 64177.0 / 0.2083 / 6.5 / 0.013 / 0.002 / 96
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 45389.0 / 0.12643678160919541 / 10.0 / 0.005 / 0.0005 / 87
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 68265.0 / 0.2396 / 5.2 / 0.013 / 0.0025 / 96
# TOTAL PARAM SIM LOOP TIME: 0.82 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 839
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 400 stop_range 6000 pip_threshold 0.005 support_low False bullish_ma None bullish_candle None candle_size 0.0005 touch_low False midpoint_offset 0.0005 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 492
# TOTAL FUNCTION TIME: 0.1248301347096761  MINUTES
# SHAPE (364, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (352, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 63449.0 / 0.1896 / 7.0 / 0.007 / 0.001 / 364
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 44014.0 / 0.09375 / 14.0 / 0.007 / 0.0005 / 352
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 59375.0 / 0.1896 / 7.0 / 0.007 / 0.001 / 364
# TOTAL PARAM SIM LOOP TIME: 0.87 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 840
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 1000 pip_threshold 0.007 support_low False bullish_ma False bullish_candle True candle_size 0.0005 touch_low True midpoint_offset -0.0015 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 820
# TOTAL FUNCTION TIME: 0.09128246307373047  MINUTES
# SHAPE (119, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (107, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 183253.0 / 0.1765 / 9.0 / 0.009 / 0.001 / 119
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 32072.0 / 0.07476635514018691 / 17.3333 / 0.013 / 0.00075 / 107
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 175444.0 / 0.1765 / 9.0 / 0.009 / 0.001 / 119
# TOTAL PARAM SIM LOOP TIME: 0.59 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 841
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 288 stop_range 8000 pip_threshold 0.007 support_low False bullish_ma None bullish_candle False candle_size 0.0005 touch_low True midpoint_offset -0.0025 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 499
# TOTAL FUNCTION TIME: 0.12587989966074625  MINUTES
# SHAPE (262, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (249, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 15383.0 / 0.5076 / 1.2 / 0.003 / 0.0025 / 262
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 18562.0 / 0.46184738955823296 / 1.5 / 0.0015 / 0.001 / 249
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 19230.0 / 0.084 / 13.0 / 0.013 / 0.001 / 262
# TOTAL PARAM SIM LOOP TIME: 0.75 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 842
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 288 stop_range 8000 pip_threshold 0.005 support_low True bullish_ma True bullish_candle True candle_size 0.0005 touch_low True midpoint_offset -0.0025 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 1046
# TOTAL FUNCTION TIME: 0.13081864913304647  MINUTES
# SHAPE (387, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (366, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 17121.5 / 0.2222 / 4.0 / 0.002 / 0.0005 / 387
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 67205.0 / 0.10382513661202186 / 14.0 / 0.007 / 0.0005 / 366
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 61508.0 / 0.0594 / 14.0 / 0.007 / 0.0005 / 387
# TOTAL PARAM SIM LOOP TIME: 0.9 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 843
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 288 stop_range 8000 pip_threshold 0.007 support_low False bullish_ma True bullish_candle None candle_size 0.001 touch_low True midpoint_offset 0.001 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 396
# TOTAL FUNCTION TIME: 0.17383883794148763  MINUTES
# SHAPE (84, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (104, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 59592.0 / 0.3333 / 3.3333 / 0.0025 / 0.00075 / 84
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 25125.5 / 0.0673076923076923 / 17.3333 / 0.013 / 0.00075 / 104
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 57719.0 / 0.3333 / 3.3333 / 0.0025 / 0.00075 / 84
# TOTAL PARAM SIM LOOP TIME: 0.74 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 844
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 100 stop_range 8000 pip_threshold 0.007 support_low False bullish_ma False bullish_candle None candle_size 0.00075 touch_low False midpoint_offset 0.001 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 667
# TOTAL FUNCTION TIME: 0.13371286392211915  MINUTES
# SHAPE (151, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (167, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 38372.5 / 0.0927 / 14.6667 / 0.011 / 0.00075 / 151
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 24847.0 / 0.19760479041916168 / 5.3333 / 0.004 / 0.00075 / 167
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 42155.0 / 0.1987 / 5.3333 / 0.004 / 0.00075 / 151
# TOTAL PARAM SIM LOOP TIME: 0.7 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 845
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 6000 pip_threshold 0.003 support_low True bullish_ma True bullish_candle True candle_size 0.0015 touch_low False midpoint_offset 0 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 827
# TOTAL FUNCTION TIME: 0.13129515250523885  MINUTES
# SHAPE (128, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (135, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 36162.0 / 0.0547 / 26.0 / 0.013 / 0.0005 / 128
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 513268.0 / 0.08148148148148149 / 26.0 / 0.013 / 0.0005 / 135
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 539430.0 / 0.0547 / 26.0 / 0.013 / 0.0005 / 128
# TOTAL PARAM SIM LOOP TIME: 0.72 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 846
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 400 stop_range 1000 pip_threshold 0.003 support_low True bullish_ma False bullish_candle None candle_size 0.0015 touch_low True midpoint_offset 0.0005 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 422
# TOTAL FUNCTION TIME: 0.15151274998982747  MINUTES
# SHAPE (64, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (51, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 222290.0 / 0.0781 / 26.0 / 0.013 / 0.0005 / 64
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 118163.0 / 0.11764705882352941 / 14.0 / 0.007 / 0.0005 / 51
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 218975.0 / 0.0781 / 26.0 / 0.013 / 0.0005 / 64
# TOTAL PARAM SIM LOOP TIME: 0.73 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 847
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 400 stop_range 6000 pip_threshold 0.003 support_low False bullish_ma False bullish_candle False candle_size 0.0005 touch_low True midpoint_offset -0.001 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 424
# TOTAL FUNCTION TIME: 0.1510786970456441  MINUTES
# SHAPE (310, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (281, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 56729.5 / 0.1065 / 13.0 / 0.013 / 0.001 / 310
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 20070.0 / 0.3914590747330961 / 2.0 / 0.004 / 0.002 / 281
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 53408.5 / 0.1839 / 7.0 / 0.007 / 0.001 / 310
# TOTAL PARAM SIM LOOP TIME: 0.91 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 848
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 100 stop_range 8000 pip_threshold 0.005 support_low True bullish_ma False bullish_candle False candle_size 0.001 touch_low True midpoint_offset 0 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 672
# TOTAL FUNCTION TIME: 0.13027685085932414  MINUTES
# SHAPE (282, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (276, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 17192.0 / 0.5 / 1.25 / 0.0025 / 0.002 / 282
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 21526.0 / 0.213768115942029 / 4.6667 / 0.007 / 0.0015 / 276
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 22880.0 / 0.1879 / 4.6667 / 0.007 / 0.0015 / 282
# TOTAL PARAM SIM LOOP TIME: 0.75 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 849
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 400 stop_range 3000 pip_threshold 0.003 support_low False bullish_ma True bullish_candle True candle_size 0.001 touch_low False midpoint_offset 0.0015 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 424
# TOTAL FUNCTION TIME: 0.14705530007680256  MINUTES
# SHAPE (31, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (33, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 87975.0 / 0.5161 / 2.0 / 0.005 / 0.0025 / 31
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 613460.5 / 0.15151515151515152 / 13.0 / 0.013 / 0.001 / 33
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 604338.5 / 0.0323 / 13.0 / 0.013 / 0.001 / 31
# TOTAL PARAM SIM LOOP TIME: 0.68 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 850
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 600 stop_range 3000 pip_threshold 0.007 support_low True bullish_ma None bullish_candle None candle_size 0.001 touch_low True midpoint_offset -0.0005 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 335
# TOTAL FUNCTION TIME: 0.16904056866963704  MINUTES
# SHAPE (148, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (134, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 513268.0 / 0.0811 / 26.0 / 0.013 / 0.0005 / 148
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 20567.0 / 0.11940298507462686 / 10.0 / 0.005 / 0.0005 / 134
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 503638.0 / 0.0811 / 26.0 / 0.013 / 0.0005 / 148
# TOTAL PARAM SIM LOOP TIME: 0.76 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 851
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 100 stop_range 8000 pip_threshold 0.005 support_low False bullish_ma None bullish_candle False candle_size 0.0015 touch_low False midpoint_offset 0.001 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 987
# TOTAL FUNCTION TIME: 0.0946672002474467  MINUTES
# SHAPE (132, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (124, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 21322.5 / 0.3333 / 2.5 / 0.0025 / 0.001 / 132
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 181417.5 / 0.1935483870967742 / 8.0 / 0.004 / 0.0005 / 124
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 179673.5 / 0.1061 / 8.0 / 0.004 / 0.0005 / 132
# TOTAL PARAM SIM LOOP TIME: 0.6 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 852
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 100 stop_range 6000 pip_threshold 0.007 support_low False bullish_ma False bullish_candle False candle_size 0.00075 touch_low False midpoint_offset 0.0015 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 667
# TOTAL FUNCTION TIME: 0.1266315499941508  MINUTES
# SHAPE (146, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (147, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 56412.0 / 0.0685 / 22.0 / 0.011 / 0.0005 / 146
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 58537.0 / 0.16326530612244897 / 8.0 / 0.004 / 0.0005 / 147
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 70038.0 / 0.1438 / 8.0 / 0.004 / 0.0005 / 146
# TOTAL PARAM SIM LOOP TIME: 0.69 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 853
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 288 stop_range 3000 pip_threshold 0.003 support_low False bullish_ma True bullish_candle False candle_size 0.0005 touch_low False midpoint_offset 0 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 579
# TOTAL FUNCTION TIME: 0.14320351680119833  MINUTES
# SHAPE (150, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (159, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 403282.0 / 0.08 / 26.0 / 0.013 / 0.0005 / 150
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 41013.0 / 0.06289308176100629 / 22.0 / 0.011 / 0.0005 / 159
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 395557.0 / 0.08 / 26.0 / 0.013 / 0.0005 / 150
# TOTAL PARAM SIM LOOP TIME: 0.8 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 854
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 8000 pip_threshold 0.007 support_low False bullish_ma False bullish_candle False candle_size 0.0005 touch_low False midpoint_offset -0.001 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 820
# TOTAL FUNCTION TIME: 0.12424436807632447  MINUTES
# SHAPE (195, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (177, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 38259.0 / 0.1692 / 7.0 / 0.007 / 0.001 / 195
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 18737.0 / 0.1638418079096045 / 6.0 / 0.003 / 0.0005 / 177
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 36648.0 / 0.3385 / 2.8 / 0.007 / 0.0025 / 195
# TOTAL PARAM SIM LOOP TIME: 0.74 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 855
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 400 stop_range 1000 pip_threshold 0.005 support_low False bullish_ma None bullish_candle None candle_size 0.00075 touch_low False midpoint_offset 0.0015 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 336
# TOTAL FUNCTION TIME: 0.19608968496322632  MINUTES
# SHAPE (146, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (159, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 42718.0 / 0.2329 / 5.0 / 0.005 / 0.001 / 146
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 95864.0 / 0.11949685534591195 / 14.0 / 0.007 / 0.0005 / 159
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 119058.0 / 0.089 / 14.0 / 0.007 / 0.0005 / 146
# TOTAL PARAM SIM LOOP TIME: 0.9 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 856
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 400 stop_range 3000 pip_threshold 0.003 support_low True bullish_ma False bullish_candle False candle_size 0.0015 touch_low True midpoint_offset 0 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 422
# TOTAL FUNCTION TIME: 0.1704916795094808  MINUTES
# SHAPE (79, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (56, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 117784.5 / 0.1519 / 10.4 / 0.013 / 0.00125 / 79
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 21084.0 / 0.6785714285714286 / 0.75 / 0.0015 / 0.002 / 56
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 111581.5 / 0.1519 / 10.4 / 0.013 / 0.00125 / 79
# TOTAL PARAM SIM LOOP TIME: 0.8 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 857
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 400 stop_range 1000 pip_threshold 0.005 support_low True bullish_ma None bullish_candle True candle_size 0.0015 touch_low False midpoint_offset 0.0005 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 495
# TOTAL FUNCTION TIME: 0.14044690132141113  MINUTES
# SHAPE (22, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (14, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 417155.0 / 0.0909 / 22.0 / 0.011 / 0.0005 / 22
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 255585.0 / 0.2857142857142857 / 5.6 / 0.007 / 0.00125 / 14
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 483907.0 / 0.0909 / 22.0 / 0.011 / 0.0005 / 22
# TOTAL PARAM SIM LOOP TIME: 0.72 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 858
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 100 stop_range 3000 pip_threshold 0.007 support_low True bullish_ma False bullish_candle None candle_size 0.0005 touch_low True midpoint_offset -0.0015 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 1719
# TOTAL FUNCTION TIME: 0.06062826712926229  MINUTES
# SHAPE (401, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (373, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 24461.0 / 0.0599 / 22.0 / 0.011 / 0.0005 / 401
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 14728.0 / 0.07506702412868632 / 14.6667 / 0.011 / 0.00075 / 373
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 18581.0 / 0.0599 / 22.0 / 0.011 / 0.0005 / 401
# TOTAL PARAM SIM LOOP TIME: 0.84 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 859
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 600 stop_range 1000 pip_threshold 0.003 support_low True bullish_ma False bullish_candle True candle_size 0.0015 touch_low False midpoint_offset -0.0005 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 721
# TOTAL FUNCTION TIME: 0.14664273659388224  MINUTES
# SHAPE (22, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (21, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 53392.5 / 0.0909 / 17.3333 / 0.013 / 0.00075 / 22
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2432797.0 / 0.14285714285714285 / 17.3333 / 0.013 / 0.00075 / 21
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2476189.5 / 0.0909 / 17.3333 / 0.013 / 0.00075 / 22
# TOTAL PARAM SIM LOOP TIME: 0.73 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 860
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 400 stop_range 6000 pip_threshold 0.005 support_low True bullish_ma False bullish_candle True candle_size 0.0015 touch_low False midpoint_offset 0.0005 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 336
# TOTAL FUNCTION TIME: 0.21322943766911825  MINUTES
# SHAPE (72, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (72, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 57304.5 / 0.2917 / 4.0 / 0.002 / 0.0005 / 72
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 193012.5 / 0.2361111111111111 / 6.6667 / 0.005 / 0.00075 / 72
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 193089.5 / 0.125 / 6.6667 / 0.005 / 0.00075 / 72
# TOTAL PARAM SIM LOOP TIME: 0.88 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 861
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 400 stop_range 6000 pip_threshold 0.007 support_low True bullish_ma True bullish_candle True candle_size 0.0005 touch_low True midpoint_offset 0.0025 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 336
# TOTAL FUNCTION TIME: 0.19707667032877604  MINUTES
# SHAPE (147, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (143, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 26714.0 / 0.1224 / 8.8 / 0.011 / 0.00125 / 147
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 84360.0 / 0.11888111888111888 / 13.0 / 0.013 / 0.001 / 143
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 78653.0 / 0.0612 / 13.0 / 0.013 / 0.001 / 147
# TOTAL PARAM SIM LOOP TIME: 0.9 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 862
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 100 stop_range 8000 pip_threshold 0.007 support_low True bullish_ma None bullish_candle True candle_size 0.0015 touch_low True midpoint_offset -0.0005 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 994
# TOTAL FUNCTION TIME: 0.09865518411000569  MINUTES
# SHAPE (137, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (151, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 653251.0 / 0.0803 / 26.0 / 0.013 / 0.0005 / 137
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 85854.0 / 0.10596026490066225 / 14.6667 / 0.011 / 0.00075 / 151
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 689276.0 / 0.0803 / 26.0 / 0.013 / 0.0005 / 137
# TOTAL PARAM SIM LOOP TIME: 0.69 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 863
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 288 stop_range 6000 pip_threshold 0.007 support_low False bullish_ma True bullish_candle False candle_size 0.00075 touch_low False midpoint_offset -0.0005 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 396
# TOTAL FUNCTION TIME: 0.18535639842351279  MINUTES
# SHAPE (122, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (129, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 96420.0 / 0.082 / 17.3333 / 0.013 / 0.00075 / 122
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 17459.0 / 0.15503875968992248 / 6.0 / 0.003 / 0.0005 / 129
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 96183.5 / 0.082 / 17.3333 / 0.013 / 0.00075 / 122
# TOTAL PARAM SIM LOOP TIME: 0.9 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 864
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 600 stop_range 3000 pip_threshold 0.005 support_low False bullish_ma True bullish_candle True candle_size 0.001 touch_low False midpoint_offset 0.0025 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 339
# TOTAL FUNCTION TIME: 0.25016939640045166  MINUTES
# SHAPE (50, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (55, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 223689.5 / 0.12 / 14.6667 / 0.011 / 0.00075 / 50
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 248965.0 / 0.07272727272727272 / 26.0 / 0.013 / 0.0005 / 55
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 240538.0 / 0.02 / 26.0 / 0.013 / 0.0005 / 50
# TOTAL PARAM SIM LOOP TIME: 0.94 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 865
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 600 stop_range 8000 pip_threshold 0.005 support_low True bullish_ma True bullish_candle False candle_size 0.0015 touch_low True midpoint_offset -0.001 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 263
# TOTAL FUNCTION TIME: 0.27452585299809773  MINUTES
# SHAPE (16, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (21, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 102892409.0 / 0.1875 / 18.0 / 0.009 / 0.0005 / 16
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 242239799.0 / 0.14285714285714285 / 26.0 / 0.013 / 0.0005 / 21
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 242304351.0 / 0.0625 / 26.0 / 0.013 / 0.0005 / 16
# TOTAL PARAM SIM LOOP TIME: 0.97 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 866
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 600 stop_range 1000 pip_threshold 0.003 support_low True bullish_ma True bullish_candle False candle_size 0.001 touch_low True midpoint_offset -0.0005 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 263
# TOTAL FUNCTION TIME: 0.23300925095876057  MINUTES
# SHAPE (12, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (7, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 153483.0 / 0.1667 / 9.3333 / 0.007 / 0.00075 / 12
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 1362437684034.0 / 0.42857142857142855 / 13.0 / 0.013 / 0.001 / 7
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 1362437690146.0 / 0.0833 / 13.0 / 0.013 / 0.001 / 12
# TOTAL PARAM SIM LOOP TIME: 0.91 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 867
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 3000 pip_threshold 0.005 support_low True bullish_ma True bullish_candle False candle_size 0.0005 touch_low False midpoint_offset 0.001 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 827
# TOTAL FUNCTION TIME: 0.11653109788894653  MINUTES
# SHAPE (118, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (136, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 28714.0 / 0.2542 / 4.0 / 0.003 / 0.00075 / 118
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 52210.5 / 0.20588235294117646 / 6.0 / 0.003 / 0.0005 / 136
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 44788.5 / 0.1017 / 6.0 / 0.003 / 0.0005 / 118
# TOTAL PARAM SIM LOOP TIME: 0.71 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 868
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 288 stop_range 1000 pip_threshold 0.007 support_low True bullish_ma False bullish_candle True candle_size 0.0005 touch_low True midpoint_offset -0.0015 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 1046
# TOTAL FUNCTION TIME: 0.0942779024442037  MINUTES
# SHAPE (341, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (311, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 49187.0 / 0.1554 / 8.0 / 0.004 / 0.0005 / 341
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 20897.0 / 0.0707395498392283 / 17.3333 / 0.013 / 0.00075 / 311
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 58896.0 / 0.1554 / 8.0 / 0.004 / 0.0005 / 341
# TOTAL PARAM SIM LOOP TIME: 0.85 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 869
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 6000 pip_threshold 0.003 support_low True bullish_ma False bullish_candle False candle_size 0.001 touch_low True midpoint_offset -0.0005 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 827
# TOTAL FUNCTION TIME: 0.14265135526657105  MINUTES
# SHAPE (223, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (198, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 118163.0 / 0.1076 / 14.0 / 0.007 / 0.0005 / 223
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 60725.5 / 0.14646464646464646 / 8.6667 / 0.013 / 0.0015 / 198
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 149281.5 / 0.1076 / 14.0 / 0.007 / 0.0005 / 223
# TOTAL PARAM SIM LOOP TIME: 0.73 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 2.473717829130335e+16 / 0.3333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987648108e+16 / 0.3333333333333333 / 26.0 / 0.013000000000000001 / 0.0005 / 3
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 2.811042987647126e+16 / 0.0 / 26.0 / 0.013000000000000001 / 0.0005 / 3
#
#
#
# LOOP NUMBER: 870
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 100 stop_range 8000 pip_threshold 0.003 support_low True bullish_ma None bullish_candle True candle_size 0.00075 touch_low True midpoint_offset 0.0005 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 672
# TOTAL FUNCTION TIME: 0.12849430243174234  MINUTES
# SHAPE (475, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (476, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 23577.0 / 0.2379 / 4.0 / 0.005 / 0.00125 / 475
# ...
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1900
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 600 stop_range 1000 pip_threshold 0.005 support_low True bullish_ma None bullish_candle False candle_size 0.0015 touch_low False midpoint_offset 0.0005 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 721
# TOTAL FUNCTION TIME: 0.2040497342745463  MINUTES
# SHAPE (73, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (50, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 36162.0 / 0.0548 / 26.0 / 0.013 / 0.0005 / 73
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 444881.0 / 0.12 / 17.3333 / 0.013 / 0.00075 / 50
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 452513.0 / 0.0685 / 17.3333 / 0.013 / 0.00075 / 73
# TOTAL PARAM SIM LOOP TIME: 1.06 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1901
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 100 stop_range 8000 pip_threshold 0.003 support_low False bullish_ma False bullish_candle False candle_size 0.001 touch_low True midpoint_offset -0.0025 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 667
# TOTAL FUNCTION TIME: 0.2409993330637614  MINUTES
# SHAPE (286, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (266, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 16045.5 / 0.3846 / 2.0 / 0.001 / 0.0005 / 286
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 63280.0 / 0.08270676691729323 / 17.3333 / 0.013 / 0.00075 / 266
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 65833.0 / 0.0594 / 17.3333 / 0.013 / 0.00075 / 286
# TOTAL PARAM SIM LOOP TIME: 1.47 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1902
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 8000 pip_threshold 0.003 support_low False bullish_ma False bullish_candle None candle_size 0.0015 touch_low False midpoint_offset -0.0025 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 820
# TOTAL FUNCTION TIME: 0.19578198194503785  MINUTES
# SHAPE (271, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (250, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 58577.0 / 0.0554 / 26.0 / 0.013 / 0.0005 / 271
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 27602.0 / 0.164 / 6.6667 / 0.005 / 0.00075 / 250
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 62359.0 / 0.0554 / 26.0 / 0.013 / 0.0005 / 271
# TOTAL PARAM SIM LOOP TIME: 1.01 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1903
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 288 stop_range 8000 pip_threshold 0.003 support_low True bullish_ma None bullish_candle True candle_size 0.001 touch_low False midpoint_offset 0.001 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 577
# TOTAL FUNCTION TIME: 0.17174525260925294  MINUTES
# SHAPE (238, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (237, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 25298.0 / 0.2899 / 3.3333 / 0.0025 / 0.00075 / 238
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 35515.5 / 0.12236286919831224 / 10.4 / 0.013 / 0.00125 / 237
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 27907.0 / 0.0756 / 8.8 / 0.011 / 0.00125 / 238
# TOTAL PARAM SIM LOOP TIME: 1.09 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1904
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 600 stop_range 6000 pip_threshold 0.007 support_low True bullish_ma True bullish_candle None candle_size 0.0015 touch_low True midpoint_offset 0.001 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 263
# TOTAL FUNCTION TIME: 0.29755280415217084  MINUTES
# SHAPE (38, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (51, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 80179.0 / 0.3947 / 2.8 / 0.007 / 0.0025 / 38
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 44993.0 / 0.5490196078431373 / 1.5 / 0.003 / 0.002 / 51
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 71476.0 / 0.3947 / 2.8 / 0.007 / 0.0025 / 38
# TOTAL PARAM SIM LOOP TIME: 1.15 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1905
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 400 stop_range 1000 pip_threshold 0.003 support_low False bullish_ma True bullish_candle False candle_size 0.00075 touch_low True midpoint_offset 0.001 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000
# COUNT: 868
# TOTAL FUNCTION TIME: 0.16376275221506756  MINUTES
# SHAPE (75, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (74, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 107878.0 / 0.3867 / 3.2 / 0.004 / 0.00125 / 75
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 235217.0 / 0.1891891891891892 / 8.6667 / 0.013 / 0.0015 / 74
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 228756.0 / 0.08 / 8.6667 / 0.013 / 0.0015 / 75
# TOTAL PARAM SIM LOOP TIME: 1.04 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1906
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 400 stop_range 8000 pip_threshold 0.003 support_low False bullish_ma True bullish_candle True candle_size 0.0005 touch_low True midpoint_offset -0.0015 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 424
# TOTAL FUNCTION TIME: 0.2837700645128886  MINUTES
# SHAPE (188, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (177, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 13077.0 / 0.5957 / 0.8 / 0.002 / 0.0025 / 188
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 61247.0 / 0.12994350282485875 / 10.4 / 0.013 / 0.00125 / 177
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 56815.5 / 0.0745 / 10.4 / 0.013 / 0.00125 / 188
# TOTAL PARAM SIM LOOP TIME: 1.4 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1907
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 288 stop_range 8000 pip_threshold 0.007 support_low False bullish_ma False bullish_candle None candle_size 0.0005 touch_low True midpoint_offset 0.001 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 1031
# TOTAL FUNCTION TIME: 0.16982003450393676  MINUTES
# SHAPE (640, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (624, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 18894.5 / 0.2344 / 4.0 / 0.005 / 0.00125 / 640
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 17543.0 / 0.22916666666666666 / 4.0 / 0.004 / 0.001 / 624
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 21021.5 / 0.2344 / 4.0 / 0.005 / 0.00125 / 640
# TOTAL PARAM SIM LOOP TIME: 2.44 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1908
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 100 stop_range 8000 pip_threshold 0.003 support_low False bullish_ma True bullish_candle True candle_size 0.00075 touch_low False midpoint_offset 0.0025 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 1694
# TOTAL FUNCTION TIME: 0.2744014779726664  MINUTES
# SHAPE (633, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (641, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 27042.0 / 0.1201 / 9.3333 / 0.007 / 0.00075 / 633
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 18271.5 / 0.19500780031201248 / 5.0 / 0.005 / 0.001 / 641
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 26254.5 / 0.0885 / 14.0 / 0.007 / 0.0005 / 633
# TOTAL PARAM SIM LOOP TIME: 3.24 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1909
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 600 stop_range 8000 pip_threshold 0.003 support_low True bullish_ma True bullish_candle None candle_size 0.0005 touch_low True midpoint_offset -0.0025 bound_pips 0.00025
# GETTING SUPPORT INDICATOR
# STOP RANGE: 8000
# COUNT: 721
# TOTAL FUNCTION TIME: 0.4625354369481405  MINUTES
# SHAPE (264, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (245, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 28413.0 / 0.0492 / 26.0 / 0.013 / 0.0005 / 264
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 69517.5 / 0.0653061224489796 / 22.0 / 0.011 / 0.0005 / 245
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 64595.5 / 0.0379 / 22.0 / 0.011 / 0.0005 / 264
# TOTAL PARAM SIM LOOP TIME: 1.97 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1910
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 288 lookup_range2 288 stop_range 6000 pip_threshold 0.007 support_low False bullish_ma True bullish_candle True candle_size 0.001 touch_low True midpoint_offset 0.0015 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 579
# TOTAL FUNCTION TIME: 0.28679200013478595  MINUTES
# SHAPE (150, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (170, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 23010.5 / 0.24 / 4.0 / 0.002 / 0.0005 / 150
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 54315.5 / 0.18235294117647058 / 7.0 / 0.007 / 0.001 / 170
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 46312.5 / 0.08 / 7.0 / 0.007 / 0.001 / 150
# TOTAL PARAM SIM LOOP TIME: 1.53 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1911
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 100 stop_range 3000 pip_threshold 0.005 support_low False bullish_ma True bullish_candle True candle_size 0.0015 touch_low True midpoint_offset -0.0005 bound_pips 0.0005
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 667
# TOTAL FUNCTION TIME: 0.2625777840614319  MINUTES
# SHAPE (29, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (28, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 6504519.5 / 0.1034 / 26.0 / 0.013 / 0.0005 / 29
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 120763.0 / 0.07142857142857142 / 26.0 / 0.013 / 0.0005 / 28
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 6499772.5 / 0.1034 / 26.0 / 0.013 / 0.0005 / 29
# TOTAL PARAM SIM LOOP TIME: 1.34 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1912
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 600 lookup_range2 288 stop_range 3000 pip_threshold 0.005 support_low True bullish_ma False bullish_candle None candle_size 0.0005 touch_low False midpoint_offset -0.001 bound_pips 0.0015
# GETTING SUPPORT INDICATOR
# STOP RANGE: 3000
# COUNT: 393
# TOTAL FUNCTION TIME: 0.38285048405329386  MINUTES
# SHAPE (244, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (236, 27)
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 115512.5 / 0.1639 / 8.8 / 0.011 / 0.00125 / 244
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 41118.5 / 0.09745762711864407 / 14.0 / 0.007 / 0.0005 / 236
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 116422.0 / 0.1639 / 8.8 / 0.011 / 0.00125 / 244
# TOTAL PARAM SIM LOOP TIME: 2.02 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1913
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 100 stop_range 6000 pip_threshold 0.007 support_low False bullish_ma None bullish_candle True candle_size 0.0005 touch_low False midpoint_offset -0.001 bound_pips 0.00075
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 820
# TOTAL FUNCTION TIME: 0.21831719477971395  MINUTES
# SHAPE (177, 27)
# GETTING RESISTANCE INDICATOR
# SHAPE (168, 27)
# ERROR WITH THESE PARAMETERS... SKIPPING
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.5890879814496907e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 5.659823948330427e+32 / 1.0 / 18.0 / 0.009 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 1913
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 400 lookup_range2 400 stop_range 1000 pip_threshold 0.007 support_low True bullish_ma None bullish_candle False candle_size 0.00075 touch_low True midpoint_offset -0.0005 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 1000

# %%
def get_support(df,lookup_range = 1500,lookup_range2 = 2400,stop_range = 2200,pip_threshold = .005,pip_threshold2 = .005,trading_session = 'london',signal =  'bullish_engulfing'):
    print('GETTING SUPPORT INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    o_col = df.columns.get_loc('o')
    l_col = df.columns.get_loc('l')
    df['support_lookup'] = 0
    df['support_indicator'] = 0

    lookup_col = df.columns.get_loc('support_lookup')
    new_col = df.columns.get_loc('support_indicator')
    trading_session_col = df.columns.get_loc(trading_session)
    signal_col = df.columns.get_loc(signal)
    arr = df.values
    min_count = 0
    print('STOP RANGE:',stop_range)
    c = 0 
    #for i in range(100000):
    for i in range(arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            min_ = min(arr[i - lookup_range : i + lookup_range2,l_col])
            
            if arr[i,l_col] == min_:
               # print(min_, max(arr[i : i + stop_range,c_col]),'RANGE:',i + 30,i + stop_range)

                lookup_ind = i
                val = arr[i,l_col]
                lookup_check = 0
                max_ = max(arr[i : i + lookup_range2,c_col])
                pip_range = max_ - min_
                c = c + 1
                if pip_threshold <=  pip_range:
                    
                    for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                        #print('VAL',(max(arr[i : j,c_col]) - min_))
                        if arr[j,l_col] <= val - pip_threshold2 and lookup_check == 0:# and arr[j,trading_session_col] == 1:
                       
   
                            arr[j,new_col] = 1
                            arr[j,lookup_col] = lookup_ind
                            lookup_check = 1
                            break
                      
        except:
            pass
        
    print('COUNT:',c)
    e = time.time()
    print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['support_indicator'] == 1].shape)
    return df








if 'JPY' in pair:
    pip_threshold = .3
    pip_threshold = .1
    pip_threshold2 = 0
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
else:
    pip_threshold = .005
    pip_threshold2 = .001
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
#pip_threshold2s = [.0005,.001,.0015,.002,.0025]
#pip_thresholds = [.003,.005,.0075]
#lookup_ranges = [500,1000,1500,2000,2500]
#lookup_range2s = [500,1000,1500,2000,2500]
#stop_ranges = [12500,10000,7500,5000,2500]


cols = [
    'instrument'
    ,'timeframe'
    ,'buy_or_sell'
    ,'trade_strategy'
   ,'median_sim_ending_val'
    ,'starting_val'
    ,'sl'
    ,'tp'
    ,'RR'
    ,'win_rate'
    ,'pip_threshold'
    ,'pip_threshold2'
    ,'lookup_range'
    ,'lookup_range2'
    ,'stop_range'
    ,'num_trades'
    ,'risk_size' 
    ,'actual_number_of_trades'
    
]


lookup_range = 288 # 1 day
#lookup_range = 450
lookup_range2 = 288 # 1 day
lookup_range2 = 288
stop_range = 3000

signal = 'bullish_engulfing'

signal = 'bullish_tls'
signal = 'bearish_tls'
signal = 'bearish_engulfing'
signal = 'bearish_tls'
signal = 'bullish_tls'
signal = 'bearish_engulfing'
signal = 'bullish_engulfing'



buy_or_sell = 1
df = get_support(df,lookup_range = lookup_range,lookup_range2 = lookup_range2,stop_range = stop_range,
                  pip_threshold = pip_threshold,pip_threshold2 = pip_threshold2,trading_session = 'london',signal =  signal)
    

trade_strategy = 'support_indicator'
#trade_strategy = 'resistance_indicatorc'
num_trades = 400
risk_size = .01
actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
starting_val = 10000
instrument = pair
timeframe = 'M5'
temp_lst = []
for sl in sls:
    for tp in tps:
        ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'buy',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

        ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'sell',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

final_df = pd.DataFrame(temp_lst,columns = cols)
final_df = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
final_df.head(10)

# %%
def get_support(df,lookup_range = 1500,lookup_range2 = 2400,stop_range = 2200,pip_threshold = .005,pip_threshold2 = .005,trading_session = 'london',signal =  'bullish_engulfing'):
    print('GETTING SUPPORT INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    o_col = df.columns.get_loc('o')
    l_col = df.columns.get_loc('l')
    h_col = df.columns.get_loc('h')
    df['support_lookup'] = 0
    df['support_indicator'] = 0

    lookup_col = df.columns.get_loc('support_lookup')
    new_col = df.columns.get_loc('support_indicator')
    trading_session_col = df.columns.get_loc(trading_session)
    signal_col = df.columns.get_loc(signal)
    arr = df.values
    min_count = 0
    print('STOP RANGE:',stop_range)
    c = 0 
    #for i in range(100000):
    for i in range(arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            min_ = min(arr[i - lookup_range : i + lookup_range2,l_col])
            
            if arr[i,l_col] == min_:
               # print(min_, max(arr[i : i + stop_range,c_col]),'RANGE:',i + 30,i + stop_range)

                lookup_ind = i
                val = arr[i,l_col]
                lookup_check = 0
                max_ = max(arr[i : i + lookup_range2,c_col])
                pip_range = max_ - min_
                c = c + 1
                if pip_threshold <=  pip_range:
                    
                    for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                        #print('VAL',(max(arr[i : j,c_col]) - min_))
                        if arr[j,l_col] <= val + pip_threshold2 and lookup_check == 0:# and arr[j,trading_session_col] == 1:
                            for k in range(j + 1, j + 48):
                                if arr[k,o_col] - arr[k,c_col] >= .0015 and arr[k,o_col] > val - .002 and arr[k,c_col] < val:
                       
   
                                    arr[k,new_col] = 1
                                    arr[k,lookup_col] = lookup_ind
                                    lookup_check = 1
                                    break
                      
        except:
            pass
        
    print('COUNT:',c)
    e = time.time()
    print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['support_indicator'] == 1].shape)
    return df








if 'JPY' in pair:
    pip_threshold = .3
    pip_threshold = .1
    pip_threshold2 = 0
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
else:
    pip_threshold = .005
    pip_threshold2 = .0005
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
#pip_threshold2s = [.0005,.001,.0015,.002,.0025]
#pip_thresholds = [.003,.005,.0075]
#lookup_ranges = [500,1000,1500,2000,2500]
#lookup_range2s = [500,1000,1500,2000,2500]
#stop_ranges = [12500,10000,7500,5000,2500]


cols = [
    'instrument'
    ,'timeframe'
    ,'buy_or_sell'
    ,'trade_strategy'
   ,'median_sim_ending_val'
    ,'starting_val'
    ,'sl'
    ,'tp'
    ,'RR'
    ,'win_rate'
    ,'pip_threshold'
    ,'pip_threshold2'
    ,'lookup_range'
    ,'lookup_range2'
    ,'stop_range'
    ,'num_trades'
    ,'risk_size' 
    ,'actual_number_of_trades'
    
]


lookup_range = 288 # 1 day
lookup_range = 100
lookup_range2 = 288 # 1 day
lookup_range2 = 100
stop_range = 2000

signal = 'bullish_engulfing'

signal = 'bullish_tls'
signal = 'bearish_tls'
signal = 'bearish_engulfing'
signal = 'bearish_tls'
signal = 'bullish_tls'
signal = 'bearish_engulfing'
signal = 'bullish_engulfing'



buy_or_sell = 1
df = get_support(df,lookup_range = lookup_range,lookup_range2 = lookup_range2,stop_range = stop_range,
                  pip_threshold = pip_threshold,pip_threshold2 = pip_threshold2,trading_session = 'london',signal =  signal)
    

trade_strategy = 'support_indicator'
#trade_strategy = 'resistance_indicatorc'
num_trades = 400
risk_size = .01
actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
starting_val = 10000
instrument = pair
timeframe = 'M5'
temp_lst = []
for sl in sls:
    for tp in tps:
        ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'buy',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

        ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'sell',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

final_df = pd.DataFrame(temp_lst,columns = cols)
final_df = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
final_df.head(10)

# %%
def get_support(df,lookup_range = 1500,lookup_range2 = 2400,stop_range = 2200,pip_threshold = .005,pip_threshold2 = .005,trading_session = 'london',signal =  'bullish_engulfing'):
    print('GETTING SUPPORT INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    o_col = df.columns.get_loc('o')
    l_col = df.columns.get_loc('l')
    h_col = df.columns.get_loc('h')
    df['support_lookup'] = 0
    df['support_indicator'] = 0

    lookup_col = df.columns.get_loc('support_lookup')
    new_col = df.columns.get_loc('support_indicator')
    trading_session_col = df.columns.get_loc(trading_session)
    signal_col = df.columns.get_loc(signal)
    arr = df.values
    min_count = 0
    print('STOP RANGE:',stop_range)
    c = 0 
    #for i in range(100000):
    for i in range(arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            min_ = min(arr[i - lookup_range : i + lookup_range2,l_col])
            
            if arr[i,l_col] == min_:
               # print(min_, max(arr[i : i + stop_range,c_col]),'RANGE:',i + 30,i + stop_range)

                lookup_ind = i
                val = arr[i,l_col]
                lookup_check = 0
                max_ = max(arr[i : i + lookup_range2,c_col])
                pip_range = max_ - min_
                c = c + 1
                if pip_threshold <=  pip_range:
                    
                    for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                        #print('VAL',(max(arr[i : j,c_col]) - min_))
                        if arr[j,l_col] <= val + pip_threshold2 and min(arr[i:j,c_col]) >= val - .0025 and arr[j,c_col] - arr[j,o_col] >= .001 and lookup_check == 0:# and arr[j,trading_session_col] == 1:

                            arr[j,new_col] = 1
                            arr[j,lookup_col] = lookup_ind
                            lookup_check = 1
                            break
                      
        except:
            pass
        
    print('COUNT:',c)
    e = time.time()
    print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['support_indicator'] == 1].shape)
    return df








if 'JPY' in pair:
    pip_threshold = .3
    pip_threshold = .1
    pip_threshold2 = 0
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
else:
    pip_threshold = .005
    pip_threshold2 = .002
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
#pip_threshold2s = [.0005,.001,.0015,.002,.0025]
#pip_thresholds = [.003,.005,.0075]
#lookup_ranges = [500,1000,1500,2000,2500]
#lookup_range2s = [500,1000,1500,2000,2500]
#stop_ranges = [12500,10000,7500,5000,2500]


cols = [
    'instrument'
    ,'timeframe'
    ,'buy_or_sell'
    ,'trade_strategy'
   ,'median_sim_ending_val'
    ,'starting_val'
    ,'sl'
    ,'tp'
    ,'RR'
    ,'win_rate'
    ,'pip_threshold'
    ,'pip_threshold2'
    ,'lookup_range'
    ,'lookup_range2'
    ,'stop_range'
    ,'num_trades'
    ,'risk_size' 
    ,'actual_number_of_trades'
    
]


lookup_range = 288 # 1 day
lookup_range = 100
lookup_range2 = 288 # 1 day
lookup_range2 = 100
stop_range = 5000

signal = 'bullish_engulfing'

signal = 'bullish_tls'
signal = 'bearish_tls'
signal = 'bearish_engulfing'
signal = 'bearish_tls'
signal = 'bullish_tls'
signal = 'bearish_engulfing'
signal = 'bullish_engulfing'



buy_or_sell = 1
df = get_support(df,lookup_range = lookup_range,lookup_range2 = lookup_range2,stop_range = stop_range,
                  pip_threshold = pip_threshold,pip_threshold2 = pip_threshold2,trading_session = 'london',signal =  signal)
    

trade_strategy = 'support_indicator'
#trade_strategy = 'resistance_indicatorc'
num_trades = 400
risk_size = .01
actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
starting_val = 10000
instrument = pair
timeframe = 'M5'
temp_lst = []
for sl in sls:
    for tp in tps:
        ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'buy',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

        ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'sell',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

final_df = pd.DataFrame(temp_lst,columns = cols)
final_df = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
final_df.head(10)

# %%
def get_support(df,lookup_range = 1500,lookup_range2 = 2400,stop_range = 2200,pip_threshold = .005,pip_threshold2 = .005,trading_session = 'london',signal =  'bullish_engulfing'):
    print('GETTING SUPPORT INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    o_col = df.columns.get_loc('o')
    l_col = df.columns.get_loc('l')
    h_col = df.columns.get_loc('h')
    df['support_lookup'] = 0
    df['support_indicator'] = 0

    lookup_col = df.columns.get_loc('support_lookup')
    new_col = df.columns.get_loc('support_indicator')
    trading_session_col = df.columns.get_loc(trading_session)
    signal_col = df.columns.get_loc(signal)
    arr = df.values
    min_count = 0
    print('STOP RANGE:',stop_range)
    c = 0 
    #for i in range(100000):
    for i in range(arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            min_ = min(arr[i - lookup_range : i + lookup_range2,l_col])
            
            if arr[i,l_col] == min_:
               # print(min_, max(arr[i : i + stop_range,c_col]),'RANGE:',i + 30,i + stop_range)

                lookup_ind = i
                val = arr[i,l_col]
                lookup_check = 0
                max_ = max(arr[i : i + lookup_range2,c_col])
                pip_range = max_ - min_
                c = c + 1
                if pip_threshold <=  pip_range:
                    
                    for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                        #print('VAL',(max(arr[i : j,c_col]) - min_))
                        if arr[j,l_col] <= val + pip_threshold2 and lookup_check == 0:
                            for k in range(j+1,j + 60):
                                if arr[k,c_col] <= val + .00025 and arr[k,c_col] >= val - .0015 and arr[k,o_col] - arr[k,c_col] >= .001:
  
                                    arr[k,new_col] = 1
                                    arr[k,lookup_col] = lookup_ind
                                    lookup_check = 1
                                    break
                      
        except:
            pass
        
    print('COUNT:',c)
    e = time.time()
    print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['support_indicator'] == 1].shape)
    return df








if 'JPY' in pair:
    pip_threshold = .3
    pip_threshold = .1
    pip_threshold2 = 0
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
else:
    pip_threshold = .005
    pip_threshold2 = .0003
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
#pip_threshold2s = [.0005,.001,.0015,.002,.0025]
#pip_thresholds = [.003,.005,.0075]
#lookup_ranges = [500,1000,1500,2000,2500]
#lookup_range2s = [500,1000,1500,2000,2500]
#stop_ranges = [12500,10000,7500,5000,2500]


cols = [
    'instrument'
    ,'timeframe'
    ,'buy_or_sell'
    ,'trade_strategy'
   ,'median_sim_ending_val'
    ,'starting_val'
    ,'sl'
    ,'tp'
    ,'RR'
    ,'win_rate'
    ,'pip_threshold'
    ,'pip_threshold2'
    ,'lookup_range'
    ,'lookup_range2'
    ,'stop_range'
    ,'num_trades'
    ,'risk_size' 
    ,'actual_number_of_trades'
    
]


lookup_range = 288 # 1 day
#lookup_range = 100
lookup_range2 = 288 # 1 day
lookup_range2 = 100
stop_range = 5000

signal = 'bullish_engulfing'

signal = 'bullish_tls'
signal = 'bearish_tls'
signal = 'bearish_engulfing'
signal = 'bearish_tls'
signal = 'bullish_tls'
signal = 'bearish_engulfing'
signal = 'bullish_engulfing'



buy_or_sell = 1
df = get_support(df,lookup_range = lookup_range,lookup_range2 = lookup_range2,stop_range = stop_range,
                  pip_threshold = pip_threshold,pip_threshold2 = pip_threshold2,trading_session = 'london',signal =  signal)
    

trade_strategy = 'support_indicator'
#trade_strategy = 'resistance_indicatorc'
num_trades = 400
risk_size = .01
actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
starting_val = 10000
instrument = pair
timeframe = 'M5'
temp_lst = []
for sl in sls:
    for tp in tps:
        ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'buy',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

        ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'sell',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

final_df = pd.DataFrame(temp_lst,columns = cols)
final_df = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
final_df.head(10)

# %%
def get_support(df,lookup_range = 1500,lookup_range2 = 2400,stop_range = 2200,pip_threshold = .005,pip_threshold2 = .005,trading_session = 'london',signal =  'bullish_engulfing'):
    print('GETTING SUPPORT INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    o_col = df.columns.get_loc('o')
    l_col = df.columns.get_loc('l')
    h_col = df.columns.get_loc('h')
    df['support_lookup'] = 0
    df['support_indicator'] = 0

    lookup_col = df.columns.get_loc('support_lookup')
    new_col = df.columns.get_loc('support_indicator')
    trading_session_col = df.columns.get_loc(trading_session)
    signal_col = df.columns.get_loc(signal)
    arr = df.values
    min_count = 0
    print('STOP RANGE:',stop_range)
    c = 0 
    #for i in range(100000):
    for i in range(arr.shape[0]):
        if i % 200000 == 0:
            print(i)
        try:
            min_ = min(arr[i - lookup_range : i + lookup_range2,l_col])
            
            if arr[i,l_col] == min_:
               # print(min_, max(arr[i : i + stop_range,c_col]),'RANGE:',i + 30,i + stop_range)

                lookup_ind = i
                val = arr[i,l_col]
                lookup_check = 0
                max_ = max(arr[i : i + lookup_range2,c_col])
                pip_range = max_ - min_
                c = c + 1
                if pip_threshold <=  pip_range:
                    
                    for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                        #print('VAL',(max(arr[i : j,c_col]) - min_))
                        if arr[j,o_col] <= val + .001 and arr[j,c_col] >= val -  .001  and arr[j,c_col] - arr[j,o_col] >= .001 and lookup_check == 0 and arr[j+1,c_col] - arr[j+1,o_col] >= .0001 and arr[j+2,o_col] - arr[j+2,c_col] >= .0001:
                        #if arr[j,l_col] <= val and arr[j,c_col] >= val - pip_threshold2  and arr[j+10,c_col] - arr[j,o_col] >= .0025 and arr[j+10,c_col] >= val and lookup_check == 0:
                            arr[j+2,new_col] = 1
                            arr[j+2,lookup_col] = lookup_ind
                            lookup_check = 1
                            break
                      
        except:
            pass
        
    print('COUNT:',c)
    e = time.time()
    print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['support_indicator'] == 1].shape)
    return df








if 'JPY' in pair:
    pip_threshold = .3
    pip_threshold = .1
    pip_threshold2 = 0
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
else:
    pip_threshold = .005
    pip_threshold2 = .0025
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
#pip_threshold2s = [.0005,.001,.0015,.002,.0025]
#pip_thresholds = [.003,.005,.0075]
#lookup_ranges = [500,1000,1500,2000,2500]
#lookup_range2s = [500,1000,1500,2000,2500]
#stop_ranges = [12500,10000,7500,5000,2500]


cols = [
    'instrument'
    ,'timeframe'
    ,'buy_or_sell'
    ,'trade_strategy'
   ,'median_sim_ending_val'
    ,'starting_val'
    ,'sl'
    ,'tp'
    ,'RR'
    ,'win_rate'
    ,'pip_threshold'
    ,'pip_threshold2'
    ,'lookup_range'
    ,'lookup_range2'
    ,'stop_range'
    ,'num_trades'
    ,'risk_size' 
    ,'actual_number_of_trades'
    
]


lookup_range = 288 # 1 day
lookup_range = 100
lookup_range2 = 288 # 1 day
lookup_range2 = 100
stop_range = 4000

signal = 'bullish_engulfing'

signal = 'bullish_tls'
signal = 'bearish_tls'
signal = 'bearish_engulfing'
signal = 'bearish_tls'
signal = 'bullish_tls'
signal = 'bearish_engulfing'
signal = 'bullish_engulfing'



buy_or_sell = 1
df = get_support(df,lookup_range = lookup_range,lookup_range2 = lookup_range2,stop_range = stop_range,
                  pip_threshold = pip_threshold,pip_threshold2 = pip_threshold2,trading_session = 'london',signal =  signal)
    

trade_strategy = 'support_indicator'
#trade_strategy = 'resistance_indicatorc'
num_trades = 400
risk_size = .01
actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
starting_val = 10000
instrument = pair
timeframe = 'M5'
temp_lst = []
for sl in sls:
    for tp in tps:
        ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'buy',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

        ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'sell',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

final_df = pd.DataFrame(temp_lst,columns = cols)
final_df = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
final_df.head(10)

# %%
240 * .15

# %%
c = 0
final_list = []
pip_threshold2s = [.0005,.001,.0015,.002,.0025]
pip_thresholds = [.003,.005,.0075]
lookup_ranges = [500,1000,1500,2000,2500]
lookup_range2s = [500,1000,1500,2000,2500]
stop_ranges = [12500,10000,7500,5000,2500]


pip_threshold2s = [.0005,.001,.0015,.002,.0025]
pip_thresholds = [.003,.005,.0075]
lookup_ranges = [1500,2000,2500]
lookup_range2s = [1000,1500,2000]
stop_ranges = [10000]

sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
tps = [.0015,.002,.0025,.003,.004,.005,.007,.009]
num_trades = 200
risk_size = .01
for pip_threshold in pip_thresholds:
    for pip_threshold2 in pip_threshold2s:
        for lookup_range in lookup_ranges:
            for lookup_range2 in lookup_range2s:
                for stop_range in stop_ranges:

# %% [markdown]
# # PARAMETERS
# ## lookup range, lookup range 2,stop range, how large the candle is, bullish vs bearish, support defined by low or close,
# ## upper and lower range of tap window, midpoint of tap window relative to support, sls and tps, next candle bullish vs bearish? (or other confluence signal?)

# %%
def strategy_tester_buy(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING BUY SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            trade_id = 0
            try:
                for j in range(i + 1,i + 20000):
                    if i not in trade_list:
                        if trade_id == 0:
                            if arr[j,l_col] <= val - sl:
                                trade_res.append(-10)
                                trade_list.append(i)
                                losses.append(i)
                                trade_id = 1

                                break
                            elif arr[j,h_col] >= val + tp:
                                trade_res.append(50)
                                trade_list.append(i)
                                wins.append(i)
                                trade_id = 1
                                break
            except:
                pass
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
    vals = []


    acc_val = 10000

    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate,wins,losses

def strategy_tester_sell(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):
    print()
    print('RUNNING SELL SIMULATOR','SL',sl,'TP',tp)
    col_num = df.columns.get_loc(col)
    h_col = df.columns.get_loc('h')
    l_col = df.columns.get_loc('l')
    c_col = df.columns.get_loc('c')
    entry_col = df.columns.get_loc(entry)
    arr = df.values
    temp_df = df[df[col] == 1]
    print('SHAPE:',temp_df.shape)    
    trade_list = []
    trade_res = []
    wins = []
    losses = []
    for i in range(arr.shape[0]):

        if arr[i,col_num] == 1:
            val = arr[i,entry_col]
            try:
                for j in range(i + 1,i + 20000):
                    if i not in trade_list:
                        if arr[j,h_col] >= val + sl:
                            trade_res.append(-10)
                            trade_list.append(i)
                            losses.append(i)
                            break
                        elif arr[j,l_col] <= val - tp:
                            trade_res.append(50)
                            trade_list.append(i)
                            wins.append(i)
                            break
            except:
                pass
    win_rate = len(wins) / len(trade_list)
    rr = tp / sl
    vals = []

    acc_val = 10000

    for i in range(30):

        final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
        vals.append(final_val)


    print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
    return np.median(vals),win_rate,wins,losses

def get_support(df,
                lookup_range = 1500,
                lookup_range2 = 2400,
                stop_range = 2200,
                pip_threshold = .005,
                support_low = True,
               bullish_ma = True,
                bullish_candle = True,
                candle_size = .001,
                touch_low = True,
                midpoint_offset = 0,
                bound_pips = .001
               ):
    print('GETTING SUPPORT INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    o_col = df.columns.get_loc('o')
    l_col = df.columns.get_loc('l')
    h_col = df.columns.get_loc('h')
    uw_col = df.columns.get_loc('upper_wick')
    lw_col = df.columns.get_loc('lower_wick')
    dv_col = df.columns.get_loc('delta_vector')
    dm_col = df.columns.get_loc('delta_max')
    d_col = df.columns.get_loc('delta')
    ma1_col = df.columns.get_loc('smma_21')
    ma2_col = df.columns.get_loc('smma_50')
    ma3_col = df.columns.get_loc('smma_200')    
    
    df['support_lookup'] = 0
    df['support_indicator'] = 0

    lookup_col = df.columns.get_loc('support_lookup')
    new_col = df.columns.get_loc('support_indicator')
    
    if support_low:
        reversal_col = df.columns.get_loc('l')
    else:
        reversal_col = df.columns.get_loc('c')
        
    if touch_low:
        touch_col = df.columns.get_loc('l')
    else:
        touch_col = df.columns.get_loc('c')    

    arr = df.values
    min_count = 0
    
    print('STOP RANGE:',stop_range)
    c = 0 
    
#['time', 'volume', 'o', 'h', 'l', 'c', 'utc_timestamp', 'est_timestamp',
 #      'smma_21', 'smma_50', 'smma_200', 'ema_42', 'ema_150', 'ema_600',
  #     'bearish_engulfing', 'bullish_engulfing', 'bearish_tls', 'bullish_tls',
   #    'new_york', 'london', 'delta_vector', 'delta_max', 'upper_wick',
    #   'lower_wick', 'delta']

    for i in range(arr.shape[0]):
       # if i % 200000 == 0:
        #    print(i)
        try:
            #DEFINE SUPPORT/RESISTANCE as the MIN or MAX of a lookup range
            min_ = min(arr[i - lookup_range : i + lookup_range2,reversal_col])
            
            # If the current val is at that reversal point:
            # Check and make sure we have an adequate movement off of that reversal point
            # this is defined by the pip_range and pip threshold, pip threshold is a user defined parameter
            if arr[i,reversal_col] == min_:
                lookup_ind = i
                val = arr[i,reversal_col]
                lookup_check = 0
                max_ = max(arr[i : i + lookup_range2,c_col])
                pip_range = max_ - min_
                c = c + 1
                if pip_threshold <= pip_range:
                    # Now that all of these conditions are met
                    # We need to look into the future to see if we hit this reversal level, this is defined by the stop range
                    for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                        #If all of the following conditions are met, we will mark the array with a 1 signal to indicated we would place a trade                       
                        #CANDLE BULL OR BEAR
                        if arr[j,c_col] >= arr[j,o_col]:
                            bull = True
                        else:
                            bull = False
                        #MOVING AVG INDICATOR
                        if bullish_ma == True:
                            if arr[j,ma1_col] > arr[j,ma2_col] and arr[j,ma2_col] > arr[j,ma3_col]:
                                ma_indicator = 1
                            else:
                                ma_indicator = 0
                        elif bullish_ma == False:
                            if arr[j,ma1_col] < arr[j,ma2_col] and arr[j,ma2_col] < arr[j,ma3_col]:
                                ma_indicator = 1
                            else:
                                ma_indicator = 0                        
                        else:
                            ma_indicator = 1
                        
                        midpoint = val + midpoint_offset
                        lower_bound = midpoint - bound_pips
                        upper_bound = midpoint + bound_pips

                        if lookup_check == 0 and \
                        ma_indicator == 1 and\
                        (bull == bullish_candle or bullish_candle == None) and\
                        arr[j,d_col] >= candle_size and\
                        (arr[j,touch_col] >= lower_bound and arr[j,touch_col] <= upper_bound):

                            arr[j,new_col] = 1
                            arr[j,lookup_col] = lookup_ind
                            lookup_check = 1
                            break
                      
        except:
            pass
        
    print('COUNT:',c)

    e = time.time()
    print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['support_indicator'] == 1].shape)
    return df


def get_resistance(df,
                lookup_range = 1500,
                lookup_range2 = 2400,
                stop_range = 2200,
                pip_threshold = .005,
                support_low = True,
               bullish_ma = True,
                bullish_candle = True,
                candle_size = .001,
                touch_low = True,
                midpoint_offset = 0,
                bound_pips = .001
               ):
    print('GETTING RESISTANCE INDICATOR')
    s = time.time()
    c_col = df.columns.get_loc('c')
    o_col = df.columns.get_loc('o')
    l_col = df.columns.get_loc('l')
    h_col = df.columns.get_loc('h')
    uw_col = df.columns.get_loc('upper_wick')
    lw_col = df.columns.get_loc('lower_wick')
    dv_col = df.columns.get_loc('delta_vector')
    dm_col = df.columns.get_loc('delta_max')
    d_col = df.columns.get_loc('delta')
    ma1_col = df.columns.get_loc('smma_21')
    ma2_col = df.columns.get_loc('smma_50')
    ma3_col = df.columns.get_loc('smma_200')    
    
    df['resistance_lookup'] = 0
    df['resistance_indicator'] = 0

    lookup_col = df.columns.get_loc('resistance_lookup')
    new_col = df.columns.get_loc('resistance_indicator')
    
    if support_low:
        reversal_col = df.columns.get_loc('h')
    else:
        reversal_col = df.columns.get_loc('c')
        
    if touch_low:
        touch_col = df.columns.get_loc('h')
    else:
        touch_col = df.columns.get_loc('c')    

    arr = df.values
    min_count = 0
    c = 0
    for i in range(arr.shape[0]):

        try:
            #DEFINE SUPPORT/RESISTANCE as the MIN or MAX of a lookup range
            max_ = max(arr[i - lookup_range : i + lookup_range2,reversal_col])
            
            # If the current val is at that reversal point:
            # Check and make sure we have an adequate movement off of that reversal point
            # this is defined by the pip_range and pip threshold, pip threshold is a user defined parameter
            if arr[i,reversal_col] == max_:
                lookup_ind = i
                val = arr[i,reversal_col]
                lookup_check = 0
                min_ = min(arr[i : i + lookup_range2,c_col])
                pip_range = max_ - min_
                c = c + 1
                if pip_threshold <= pip_range:
                    # Now that all of these conditions are met
                    # We need to look into the future to see if we hit this reversal level, this is defined by the stop range
                    for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                        #If all of the following conditions are met, we will mark the array with a 1 signal to indicated we would place a trade                       
                        #CANDLE BULL OR BEAR
                        if arr[j,c_col] >= arr[j,o_col]:
                            bull = True
                        else:
                            bull = False
                        #MOVING AVG INDICATOR
                        if bullish_ma == True:
                            if arr[j,ma1_col] > arr[j,ma2_col] and arr[j,ma2_col] > arr[j,ma3_col]:
                                ma_indicator = 1
                            else:
                                ma_indicator = 0
                        elif bullish_ma == False:
                            if arr[j,ma1_col] < arr[j,ma2_col] and arr[j,ma2_col] < arr[j,ma3_col]:
                                ma_indicator = 1
                            else:
                                ma_indicator = 0                        
                        else:
                            ma_indicator = 1
                        
                        midpoint = val + midpoint_offset
                        lower_bound = midpoint - bound_pips
                        upper_bound = midpoint + bound_pips

                        if lookup_check == 0 and \
                        ma_indicator == 1 and\
                        (bull == bullish_candle or bullish_candle == None) and\
                        arr[j,d_col] >= candle_size and\
                        (arr[j,touch_col] >= lower_bound and arr[j,touch_col] <= upper_bound):

                            arr[j,new_col] = 1
                            arr[j,lookup_col] = lookup_ind
                            lookup_check = 1
                            break
                      
        except:
            pass
        
    e = time.time()
    df = pd.DataFrame(arr,columns = df.columns)
    print('SHAPE',df[df['resistance_indicator'] == 1].shape)
    return df



cols = [
    'instrument'
    ,'timeframe'
    ,'buy_or_sell'
    ,'trade_strategy'
   ,'median_sim_ending_val'
    ,'median_sim_ending_val2'
    ,'total_sim_val'
    ,'starting_val'
    ,'sl'
    ,'tp'
    ,'RR'
    ,'win_rate'    
    ,'num_trades'
    ,'risk_size' 
    ,'actual_number_of_trades'   
    ,'buy_or_sell2'
    ,'trade_strategy2'
   
    ,'win_rate2'    
    ,'actual_number_of_trades2'    
    ,'lookup_range' 
    ,'lookup_range2' 
    ,'stop_range' 
    ,'pip_threshold' 
    ,'support_low' 
    ,'bullish_ma' 
    ,'bullish_candle'
    ,'candle_size' 
    ,'touch_low' 
    ,'midpoint_offset' 
    ,'bound_pips' 
    
]




# PARAM DEFINITON
if 'JPY' in pair:
    pip_threshold = .5
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
    candle_sizes = [.05,.075,.1,.15]
    midpoint_offsets = [0,-.05,.05,-.1,.1,-.15,.15,-.25,.25]
    bound_pips_ = [.025,.05,.075,.1,.15]
else:
    pip_threshold = .005
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
    candle_sizes = [.0005,.00075,.001,.0015]
    midpoint_offsets = [0,-.0005,.0005,-.001,.001,-.0015,.0015,-.0025,.0025]
    bound_pips_ = [.00025,.0005,.00075,.001,.0015]
    
lookup_ranges = [100,288,400,600]
lookup_ranges2 = [100,288,400,600]    
stop_ranges = [1000,3000,6000,8000]

support_lows = [True,False]
bullish_mas = [True,False,None]
bullish_candles = [True,False,None]
touch_lows = [True,False]

lookup_range = 250
lookup_range2 = 150
stop_range = 4500
pip_threshold = pip_threshold
support_low = True
bullish_ma = None
bullish_candle = False
candle_size = candle_sizes[2]
touch_low = touch_lows[0]
midpoint_offset = midpoint_offsets[0]
bound_pips = bound_pips_[3]


df = get_support(df,
                lookup_range = lookup_range,
                lookup_range2 = lookup_range2,
                stop_range = stop_range,
                pip_threshold = pip_threshold,
                support_low = support_low,
               bullish_ma = bullish_ma,
                bullish_candle = bullish_candle,
                candle_size = candle_size,
                touch_low = touch_low,
                midpoint_offset = midpoint_offset,
                bound_pips = bound_pips
               )

if bullish_ma == True:
    res_bullish_ma = False
elif bullish_ma == False:
    res_bullish_ma = True
else:
    res_bullish_ma = None
    
if bullish_candle == True:
    res_bullish_candle = False
elif bullish_candle == False:
    res_bullish_candle = True
else:
    res_bullish_candle = None

res_midpoint_offset = midpoint_offset * -1

df_ = get_resistance(df_,
                lookup_range = lookup_range,
                lookup_range2 = lookup_range2,
                stop_range = stop_range,
                pip_threshold = pip_threshold,
                support_low = support_low,
               bullish_ma = res_bullish_ma,
                bullish_candle = res_bullish_candle,
                candle_size = candle_size,
                touch_low = touch_low,
                midpoint_offset = res_midpoint_offset,
                bound_pips = bound_pips
               )

trade_strategy = 'support_indicator'
trade_strategy2 = 'resistance_indicator'

#trade_strategy = 'resistance_indicatorc'
num_trades = 400
risk_size = .01

starting_val = 10000
instrument = pair
timeframe = 'M5'
temp_lst = []
actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
actual_number_of_trades2 = df_[df_[trade_strategy2] == 1].shape[0]
for sl in sls:
    for tp in tps:
        ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)
        ending_val2,win_rate2,wins2,losses2 = strategy_tester_sell(df_,col = trade_strategy2,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,
                timeframe,
                'buy',
                trade_strategy,
                ending_val,
                ending_val2,
               ending_val + ending_val2 - starting_val,
                starting_val,
                sl,
                tp,
                round(tp / sl,4),
                round(win_rate,4),
                num_trades,
                risk_size,
                actual_number_of_trades,
               'sell',
                trade_strategy2,

                win_rate2,
                actual_number_of_trades2,
                lookup_range,
                lookup_range2,
                stop_range,
                pip_threshold,
                support_low ,
                bullish_ma ,
                bullish_candle ,
                candle_size ,
                touch_low ,
                midpoint_offset,
                bound_pips 
        ]
        
        temp_lst.append(lst)
        
        
        ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)
        ending_val2,win_rate2,wins2,losses2 = strategy_tester_buy(df_,col = trade_strategy2,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,
                timeframe,
                'sell',
                trade_strategy,
                ending_val,
                ending_val2,
               ending_val + ending_val2 - starting_val,
                starting_val,
                sl,
                tp,
                round(tp / sl,4),
                round(win_rate,4),
                num_trades,
                risk_size,
                actual_number_of_trades,
               'buy',
                trade_strategy2,
                win_rate2,
                actual_number_of_trades2,
                lookup_range,
                lookup_range2,
                stop_range,
                pip_threshold,
                support_low ,
                bullish_ma ,
                bullish_candle ,
                candle_size ,
                touch_low ,
                midpoint_offset,
                bound_pips 
        ]
        
        temp_lst.append(lst)
        
                
        
        
final_df = pd.DataFrame(temp_lst,columns = cols)
final_df = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
final_df.head(10)

# %%
def run_single_parameter_sim_loop(df,
                                 df_,
                                  pair,
                                 lookup_range,
                                    lookup_range2,
                                    stop_range,
                                    pip_threshold,
                                    support_low,
                                   bullish_ma,
                                    bullish_candle,
                                    candle_size,
                                    touch_low,
                                    midpoint_offset,
                                    bound_pips,sls,tps):
    
    def strategy_tester_buy(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):

        col_num = df.columns.get_loc(col)
        h_col = df.columns.get_loc('h')
        l_col = df.columns.get_loc('l')
        c_col = df.columns.get_loc('c')
        entry_col = df.columns.get_loc(entry)
        arr = df.values
        temp_df = df[df[col] == 1]
 
        trade_list = []
        trade_res = []
        wins = []
        losses = []
        for i in range(arr.shape[0]):

            if arr[i,col_num] == 1:
                val = arr[i,entry_col]
                trade_id = 0
                try:
                    for j in range(i + 1,i + 20000):
                        if i not in trade_list:
                            if trade_id == 0:
                                if arr[j,l_col] <= val - sl:
                                    trade_res.append(-10)
                                    trade_list.append(i)
                                    losses.append(i)
                                    trade_id = 1

                                    break
                                elif arr[j,h_col] >= val + tp:
                                    trade_res.append(50)
                                    trade_list.append(i)
                                    wins.append(i)
                                    trade_id = 1
                                    break
                except:
                    pass
        win_rate = len(wins) / len(trade_list)
        rr = tp / sl
        vals = []


        acc_val = 10000

        for i in range(30):

            final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
            vals.append(final_val)


        #print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
        return np.median(vals),win_rate,wins,losses

    def strategy_tester_sell(df,col = 'support_indicator',sl = .1,tp = .5,num_trades = 300,risk_size = .01,entry = 'c',pr = True):

        col_num = df.columns.get_loc(col)
        h_col = df.columns.get_loc('h')
        l_col = df.columns.get_loc('l')
        c_col = df.columns.get_loc('c')
        entry_col = df.columns.get_loc(entry)
        arr = df.values
        temp_df = df[df[col] == 1]
   
        trade_list = []
        trade_res = []
        wins = []
        losses = []
        for i in range(arr.shape[0]):

            if arr[i,col_num] == 1:
                val = arr[i,entry_col]
                try:
                    for j in range(i + 1,i + 20000):
                        if i not in trade_list:
                            if arr[j,h_col] >= val + sl:
                                trade_res.append(-10)
                                trade_list.append(i)
                                losses.append(i)
                                break
                            elif arr[j,l_col] <= val - tp:
                                trade_res.append(50)
                                trade_list.append(i)
                                wins.append(i)
                                break
                except:
                    pass
        win_rate = len(wins) / len(trade_list)
        rr = tp / sl
        vals = []

        acc_val = 10000

        for i in range(30):

            final_val = simulate_results(num_trades = num_trades,acc_val = acc_val,rr = rr,risk_size = risk_size,win_rate = win_rate,pr = pr)
            vals.append(final_val)


        #print('MEDIAN SIM:',np.median(vals),'AVG SIM:',sum(vals) / len(vals),'WIN RATE',win_rate,' RR:',rr, 'NUM TRADES:',num_trades,' RISK SIZE:',risk_size)
        return np.median(vals),win_rate,wins,losses
    
    
    def get_support(df,
                    lookup_range = 1500,
                    lookup_range2 = 2400,
                    stop_range = 2200,
                    pip_threshold = .005,
                    support_low = True,
                   bullish_ma = True,
                    bullish_candle = True,
                    candle_size = .001,
                    touch_low = True,
                    midpoint_offset = 0,
                    bound_pips = .001
                   ):
        print('GETTING SUPPORT INDICATOR')
        s = time.time()
        c_col = df.columns.get_loc('c')
        o_col = df.columns.get_loc('o')
        l_col = df.columns.get_loc('l')
        h_col = df.columns.get_loc('h')
        uw_col = df.columns.get_loc('upper_wick')
        lw_col = df.columns.get_loc('lower_wick')
        dv_col = df.columns.get_loc('delta_vector')
        dm_col = df.columns.get_loc('delta_max')
        d_col = df.columns.get_loc('delta')
        ma1_col = df.columns.get_loc('smma_21')
        ma2_col = df.columns.get_loc('smma_50')
        ma3_col = df.columns.get_loc('smma_200')    

        df['support_lookup'] = 0
        df['support_indicator'] = 0

        lookup_col = df.columns.get_loc('support_lookup')
        new_col = df.columns.get_loc('support_indicator')

        if support_low:
            reversal_col = df.columns.get_loc('l')
        else:
            reversal_col = df.columns.get_loc('c')

        if touch_low:
            touch_col = df.columns.get_loc('l')
        else:
            touch_col = df.columns.get_loc('c')    

        arr = df.values
        min_count = 0

        print('STOP RANGE:',stop_range)
        c = 0 

    #['time', 'volume', 'o', 'h', 'l', 'c', 'utc_timestamp', 'est_timestamp',
     #      'smma_21', 'smma_50', 'smma_200', 'ema_42', 'ema_150', 'ema_600',
      #     'bearish_engulfing', 'bullish_engulfing', 'bearish_tls', 'bullish_tls',
       #    'new_york', 'london', 'delta_vector', 'delta_max', 'upper_wick',
        #   'lower_wick', 'delta']

        for i in range(arr.shape[0]):
           # if i % 200000 == 0:
            #    print(i)
            try:
                #DEFINE SUPPORT/RESISTANCE as the MIN or MAX of a lookup range
                min_ = min(arr[i - lookup_range : i + lookup_range2,reversal_col])

                # If the current val is at that reversal point:
                # Check and make sure we have an adequate movement off of that reversal point
                # this is defined by the pip_range and pip threshold, pip threshold is a user defined parameter
                if arr[i,reversal_col] == min_:
                    lookup_ind = i
                    val = arr[i,reversal_col]
                    lookup_check = 0
                    max_ = max(arr[i : i + lookup_range2,c_col])
                    pip_range = max_ - min_
                    c = c + 1
                    if pip_threshold <= pip_range:
                        # Now that all of these conditions are met
                        # We need to look into the future to see if we hit this reversal level, this is defined by the stop range
                        for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                            #If all of the following conditions are met, we will mark the array with a 1 signal to indicated we would place a trade                       
                            #CANDLE BULL OR BEAR
                            if arr[j,c_col] >= arr[j,o_col]:
                                bull = True
                            else:
                                bull = False
                            #MOVING AVG INDICATOR
                            if bullish_ma == True:
                                if arr[j,ma1_col] > arr[j,ma2_col] and arr[j,ma2_col] > arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0
                            elif bullish_ma == False:
                                if arr[j,ma1_col] < arr[j,ma2_col] and arr[j,ma2_col] < arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0                        
                            else:
                                ma_indicator = 1

                            midpoint = val + midpoint_offset
                            lower_bound = midpoint - bound_pips
                            upper_bound = midpoint + bound_pips

                            if lookup_check == 0 and \
                            ma_indicator == 1 and\
                            (bull == bullish_candle or bullish_candle == None) and\
                            arr[j,d_col] >= candle_size and\
                            (arr[j,touch_col] >= lower_bound and arr[j,touch_col] <= upper_bound):

                                arr[j,new_col] = 1
                                arr[j,lookup_col] = lookup_ind
                                lookup_check = 1
                                break

            except:
                pass

        print('COUNT:',c)

        e = time.time()
        print('TOTAL FUNCTION TIME:',(e-s)/60,' MINUTES')
        df = pd.DataFrame(arr,columns = df.columns)
        print('SHAPE',df[df['support_indicator'] == 1].shape)
        return df


    def get_resistance(df,
                    lookup_range = 1500,
                    lookup_range2 = 2400,
                    stop_range = 2200,
                    pip_threshold = .005,
                    support_low = True,
                   bullish_ma = True,
                    bullish_candle = True,
                    candle_size = .001,
                    touch_low = True,
                    midpoint_offset = 0,
                    bound_pips = .001
                   ):
        print('GETTING RESISTANCE INDICATOR')
        s = time.time()
        c_col = df.columns.get_loc('c')
        o_col = df.columns.get_loc('o')
        l_col = df.columns.get_loc('l')
        h_col = df.columns.get_loc('h')
        uw_col = df.columns.get_loc('upper_wick')
        lw_col = df.columns.get_loc('lower_wick')
        dv_col = df.columns.get_loc('delta_vector')
        dm_col = df.columns.get_loc('delta_max')
        d_col = df.columns.get_loc('delta')
        ma1_col = df.columns.get_loc('smma_21')
        ma2_col = df.columns.get_loc('smma_50')
        ma3_col = df.columns.get_loc('smma_200')    

        df['resistance_lookup'] = 0
        df['resistance_indicator'] = 0

        lookup_col = df.columns.get_loc('resistance_lookup')
        new_col = df.columns.get_loc('resistance_indicator')

        if support_low:
            reversal_col = df.columns.get_loc('h')
        else:
            reversal_col = df.columns.get_loc('c')

        if touch_low:
            touch_col = df.columns.get_loc('h')
        else:
            touch_col = df.columns.get_loc('c')    

        arr = df.values
        min_count = 0
        c = 0
        for i in range(arr.shape[0]):

            try:
                #DEFINE SUPPORT/RESISTANCE as the MIN or MAX of a lookup range
                max_ = max(arr[i - lookup_range : i + lookup_range2,reversal_col])

                # If the current val is at that reversal point:
                # Check and make sure we have an adequate movement off of that reversal point
                # this is defined by the pip_range and pip threshold, pip threshold is a user defined parameter
                if arr[i,reversal_col] == max_:
                    lookup_ind = i
                    val = arr[i,reversal_col]
                    lookup_check = 0
                    min_ = min(arr[i : i + lookup_range2,c_col])
                    pip_range = max_ - min_
                    c = c + 1
                    if pip_threshold <= pip_range:
                        # Now that all of these conditions are met
                        # We need to look into the future to see if we hit this reversal level, this is defined by the stop range
                        for j in range(i + lookup_range2,i + lookup_range2 + stop_range):
                            #If all of the following conditions are met, we will mark the array with a 1 signal to indicated we would place a trade                       
                            #CANDLE BULL OR BEAR
                            if arr[j,c_col] >= arr[j,o_col]:
                                bull = True
                            else:
                                bull = False
                            #MOVING AVG INDICATOR
                            if bullish_ma == True:
                                if arr[j,ma1_col] > arr[j,ma2_col] and arr[j,ma2_col] > arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0
                            elif bullish_ma == False:
                                if arr[j,ma1_col] < arr[j,ma2_col] and arr[j,ma2_col] < arr[j,ma3_col]:
                                    ma_indicator = 1
                                else:
                                    ma_indicator = 0                        
                            else:
                                ma_indicator = 1

                            midpoint = val + midpoint_offset
                            lower_bound = midpoint - bound_pips
                            upper_bound = midpoint + bound_pips

                            if lookup_check == 0 and \
                            ma_indicator == 1 and\
                            (bull == bullish_candle or bullish_candle == None) and\
                            arr[j,d_col] >= candle_size and\
                            (arr[j,touch_col] >= lower_bound and arr[j,touch_col] <= upper_bound):

                                arr[j,new_col] = 1
                                arr[j,lookup_col] = lookup_ind
                                lookup_check = 1
                                break

            except:
                pass

        e = time.time()
        df = pd.DataFrame(arr,columns = df.columns)
        print('SHAPE',df[df['resistance_indicator'] == 1].shape)
        return df

    s = time.time()
    print('RUNNING SINGLE PARAMETER LOOP FOR PARAMS:',
          'lookup_range',lookup_range,
          'lookup_range2', lookup_range2,
                    'stop_range', stop_range,
                    'pip_threshold' , pip_threshold,
                    'support_low' , support_low,
                   'bullish_ma' , bullish_ma,
                    'bullish_candle' , bullish_candle,
                    'candle_size' , candle_size,
                    'touch_low' , touch_low,
                    'midpoint_offset' , midpoint_offset,
                    'bound_pips' , bound_pips)
    
    cols = [
        'instrument'
        ,'timeframe'
        ,'buy_or_sell'
        ,'trade_strategy'
       ,'median_sim_ending_val'
        ,'median_sim_ending_val2'
        ,'total_sim_val'
        ,'starting_val'
        ,'sl'
        ,'tp'
        ,'RR'
        ,'win_rate'    
        ,'num_trades'
        ,'risk_size' 
        ,'actual_number_of_trades'   
        ,'buy_or_sell2'
        ,'trade_strategy2'

        ,'win_rate2'    
        ,'actual_number_of_trades2'    
        ,'lookup_range' 
        ,'lookup_range2' 
        ,'stop_range' 
        ,'pip_threshold' 
        ,'support_low' 
        ,'bullish_ma' 
        ,'bullish_candle'
        ,'candle_size' 
        ,'touch_low' 
        ,'midpoint_offset' 
        ,'bound_pips' 

    ]

    df = get_support(df,
                    lookup_range = lookup_range,
                    lookup_range2 = lookup_range2,
                    stop_range = stop_range,
                    pip_threshold = pip_threshold,
                    support_low = support_low,
                   bullish_ma = bullish_ma,
                    bullish_candle = bullish_candle,
                    candle_size = candle_size,
                    touch_low = touch_low,
                    midpoint_offset = midpoint_offset,
                    bound_pips = bound_pips
                   )

    if bullish_ma == True:
        res_bullish_ma = False
    elif bullish_ma == False:
        res_bullish_ma = True
    else:
        res_bullish_ma = None

    if bullish_candle == True:
        res_bullish_candle = False
    elif bullish_candle == False:
        res_bullish_candle = True
    else:
        res_bullish_candle = None

    res_midpoint_offset = midpoint_offset * -1

    df_ = get_resistance(df_,
                    lookup_range = lookup_range,
                    lookup_range2 = lookup_range2,
                    stop_range = stop_range,
                    pip_threshold = pip_threshold,
                    support_low = support_low,
                   bullish_ma = res_bullish_ma,
                    bullish_candle = res_bullish_candle,
                    candle_size = candle_size,
                    touch_low = touch_low,
                    midpoint_offset = res_midpoint_offset,
                    bound_pips = bound_pips
                   )

    trade_strategy = 'support_indicator'
    trade_strategy2 = 'resistance_indicator'

    #trade_strategy = 'resistance_indicatorc'
    num_trades = 400
    risk_size = .01

    starting_val = 10000
    instrument = pair
    timeframe = 'M5'
    temp_lst = []
    actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
    actual_number_of_trades2 = df_[df_[trade_strategy2] == 1].shape[0]
    for sl in sls:
        for tp in tps:
            ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)
            ending_val2,win_rate2,wins2,losses2 = strategy_tester_sell(df_,col = trade_strategy2,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

            lst = [instrument,
                    timeframe,
                    'buy',
                    trade_strategy,
                    ending_val,
                    ending_val2,
                   ending_val + ending_val2 - starting_val,
                    starting_val,
                    sl,
                    tp,
                    round(tp / sl,4),
                    round(win_rate,4),
                    num_trades,
                    risk_size,
                    actual_number_of_trades,
                   'sell',
                    trade_strategy2,

                    win_rate2,
                    actual_number_of_trades2,
                    lookup_range,
                    lookup_range2,
                    stop_range,
                    pip_threshold,
                    support_low ,
                    bullish_ma ,
                    bullish_candle ,
                    candle_size ,
                    touch_low ,
                    midpoint_offset,
                    bound_pips 
            ]

            temp_lst.append(lst)


            ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)
            ending_val2,win_rate2,wins2,losses2 = strategy_tester_buy(df_,col = trade_strategy2,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

            lst = [instrument,
                    timeframe,
                    'sell',
                    trade_strategy,
                    ending_val,
                    ending_val2,
                   ending_val + ending_val2 - starting_val,
                    starting_val,
                    sl,
                    tp,
                    round(tp / sl,4),
                    round(win_rate,4),
                    num_trades,
                    risk_size,
                    actual_number_of_trades,
                   'buy',
                    trade_strategy2,
                    win_rate2,
                    actual_number_of_trades2,
                    lookup_range,
                    lookup_range2,
                    stop_range,
                    pip_threshold,
                    support_low ,
                    bullish_ma ,
                    bullish_candle ,
                    candle_size ,
                    touch_low ,
                    midpoint_offset,
                    bound_pips 
            ]

            temp_lst.append(lst)




    final_df = pd.DataFrame(temp_lst,columns = cols)
    final_df = final_df.sort_values(by = 'total_sim_val',ascending = False)
    
    support_best = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
    resistance_best = final_df.sort_values(by = 'median_sim_ending_val2',ascending = False)
    overall_best = final_df.sort_values(by = 'total_sim_val',ascending = False)

    print('SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',support_best['buy_or_sell'].iloc[0],'/',support_best['median_sim_ending_val'].iloc[0],'/',support_best['win_rate'].iloc[0],'/',support_best['RR'].iloc[0],'/',support_best['tp'].iloc[0],'/',support_best['sl'].iloc[0],'/',support_best['actual_number_of_trades'].iloc[0]
         )
    print('RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',resistance_best['buy_or_sell'].iloc[0],'/',resistance_best['median_sim_ending_val2'].iloc[0],'/',resistance_best['win_rate2'].iloc[0],'/',resistance_best['RR'].iloc[0],'/',resistance_best['tp'].iloc[0],'/',resistance_best['sl'].iloc[0],'/',resistance_best['actual_number_of_trades2'].iloc[0]
         )
    print('OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',overall_best['buy_or_sell'].iloc[0],'/',overall_best['total_sim_val'].iloc[0],'/',overall_best['win_rate'].iloc[0],'/',overall_best['RR'].iloc[0],'/',overall_best['tp'].iloc[0],'/',overall_best['sl'].iloc[0],'/',overall_best['actual_number_of_trades'].iloc[0]
         )


    e = time.time()
    print('TOTAL PARAM SIM LOOP TIME:',round((e-s)/60,2),'MINUTES')
    return final_df


def generate_random_param_list():
    def return_random_list_element(lst):
        return lst[random.randint(0,len(lst) - 1)]
    # param loop
    # PARAM DEFINITON
    if 'JPY' in pair:
        pip_thresholds = [.3,.5,.7]
        sls = [.05,.075,.1,.125,.15,.2,.25]
        tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
        candle_sizes = [.05,.075,.1,.15]
        midpoint_offsets = [0,-.05,.05,-.1,.1,-.15,.15,-.25,.25]
        bound_pips_ = [.025,.05,.075,.1,.15]
    else:
        pip_thresholds = [.003,.005,.007]
        sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
        tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
        candle_sizes = [.0005,.00075,.001,.0015]
        midpoint_offsets = [0,-.0005,.0005,-.001,.001,-.0015,.0015,-.0025,.0025]
        bound_pips_ = [.00025,.0005,.00075,.001,.0015]

    lookup_ranges = [100,288,400,600]
    lookup_ranges2 = [100,288,400,600]    
    stop_ranges = [1000,3000,6000,8000]

    support_lows = [True,False]
    bullish_mas = [True,False,None]
    bullish_candles = [True,False,None]
    touch_lows = [True,False]
    
    lookup_range = return_random_list_element(lookup_ranges)
    lookup_range2 = return_random_list_element(lookup_ranges2)
    stop_range = return_random_list_element(stop_ranges)
    pip_threshold = return_random_list_element(pip_thresholds)
    support_low = return_random_list_element(support_lows)
    bullish_ma = return_random_list_element(bullish_mas)
    bullish_candle = return_random_list_element(bullish_candles)
    candle_size = return_random_list_element(candle_sizes)
    touch_low = return_random_list_element(touch_lows)
    midpoint_offset = return_random_list_element(midpoint_offsets)
    bound_pips = return_random_list_element(bound_pips_)
    param_check_list = [lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips]
    
    return param_check_list,lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips,sls,tps



def run_sim(file,max_loops):
    print('RUNNING SIM...')
    file_name = 'SIM_CLEAN_' + file
    file_name2 = 'CHECK_PARAMS_' + file
    try:
        final_df = pd.read_csv(file_name)
        loop_number = final_df['loop_number'].max()

        param_check_df = pd.read_csv(file_name2)
        param_check_lists = param_check_df.values.tolist()

    except:
        final_df = pd.DataFrame([0])
        param_check_df = pd.DataFrame([0])
        loop_number = 0
        param_check_lists = []
    
    while max_loops >= loop_number:
        checker = 0
        while checker == 0:
            param_check_list,lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips,sls,tps = generate_random_param_list()
            if param_check_list not in param_check_lists:
                param_check_lists.append(param_check_list)

                checker = 1
        try:
            if final_df.shape[0] == 1:
                loop_number = 1
            else:
                loop_number = final_df['loop_number'].max() + 1

            print('LOOP NUMBER:',loop_number)
            loop_df = run_single_parameter_sim_loop(df,
                                                 df_,
                                                  pair,
                                                 lookup_range,
                                                    lookup_range2,
                                                    stop_range,
                                                    pip_threshold,
                                                    support_low,
                                                   bullish_ma,
                                                    bullish_candle,
                                                    candle_size,
                                                    touch_low,
                                                    midpoint_offset,
                                                    bound_pips,sls,tps)
            loop_df['loop_number'] = loop_number

            if final_df.shape[0] == 1:
                final_df = loop_df

            else:
                final_df = final_df.append(loop_df)

            final_df.to_csv(file_name,index = False)
            param_check_df = pd.DataFrame(param_check_lists)
            param_check_df.to_csv(file_name2,index = False)
        except:
            print('ERROR WITH THESE PARAMETERS... SKIPPING')

        support_best = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
        resistance_best = final_df.sort_values(by = 'median_sim_ending_val2',ascending = False)
        overall_best = final_df.sort_values(by = 'total_sim_val',ascending = False)

        print('OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',support_best['buy_or_sell'].iloc[0],'/',support_best['median_sim_ending_val'].iloc[0],'/',support_best['win_rate'].iloc[0],'/',support_best['RR'].iloc[0],'/',support_best['tp'].iloc[0],'/',support_best['sl'].iloc[0],'/',support_best['actual_number_of_trades'].iloc[0]
             )
        print('OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',resistance_best['buy_or_sell'].iloc[0],'/',resistance_best['median_sim_ending_val2'].iloc[0],'/',resistance_best['win_rate2'].iloc[0],'/',resistance_best['RR'].iloc[0],'/',resistance_best['tp'].iloc[0],'/',resistance_best['sl'].iloc[0],'/',resistance_best['actual_number_of_trades2'].iloc[0]
             )
        print('OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES:',overall_best['buy_or_sell'].iloc[0],'/',overall_best['total_sim_val'].iloc[0],'/',overall_best['win_rate'].iloc[0],'/',overall_best['RR'].iloc[0],'/',overall_best['tp'].iloc[0],'/',overall_best['sl'].iloc[0],'/',overall_best['actual_number_of_trades'].iloc[0]
             )
        print()
        print()
        print()
        

run_sim(file,max_loops = 5000)
# Out:
# SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 61644.0 / 0.3034 / 4.0 / 0.003 / 0.00075 / 89
# RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 23654.0 / 0.40625 / 2.0 / 0.005 / 0.0025 / 96
# OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 65026.5 / 0.3034 / 4.0 / 0.003 / 0.00075 / 89
# TOTAL PARAM SIM LOOP TIME: 0.72 MINUTES
# OVR SUPPORT BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 1.4067536382281777e+44 / 1.0 / 26.0 / 0.013 / 0.0005 / 1
# OVR RESISTANCE BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: buy / 1.00968472873817e+23 / 0.5 / 26.0 / 0.013 / 0.0005 / 2
# OVR OVERALL BEST BUY/VAL/WR/RR/TP/SL/NUM_TRADES: sell / 1.4067536382281777e+44 / 1.0 / 26.0 / 0.013 / 0.0005 / 1
#
#
#
# LOOP NUMBER: 805
# RUNNING SINGLE PARAMETER LOOP FOR PARAMS: lookup_range 100 lookup_range2 400 stop_range 6000 pip_threshold 0.005 support_low False bullish_ma False bullish_candle False candle_size 0.0005 touch_low True midpoint_offset 0.001 bound_pips 0.001
# GETTING SUPPORT INDICATOR
# STOP RANGE: 6000
# COUNT: 820
# TOTAL FUNCTION TIME: 0.1104964017868042  MINUTES
# SHAPE (520, 27)
# GETTING RESISTANCE INDICATOR

# %%
final_df.tail()

# %%
# param loop
# PARAM DEFINITON
if 'JPY' in pair:
    pip_thresholds = [.3,.5,.7]
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
    candle_sizes = [.05,.075,.1,.15]
    midpoint_offsets = [0,-.05,.05,-.1,.1,-.15,.15,-.25,.25]
    bound_pips_ = [.025,.05,.075,.1,.15]
else:
    pip_thresholds = [.003,.005,.007]
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
    candle_sizes = [.0005,.00075,.001,.0015]
    midpoint_offsets = [0,-.0005,.0005,-.001,.001,-.0015,.0015,-.0025,.0025]
    bound_pips_ = [.00025,.0005,.00075,.001,.0015]
    
lookup_ranges = [100,288,400,600]
lookup_ranges2 = [100,288,400,600]    
stop_ranges = [1000,3000,6000,8000]

support_lows = [True,False]
bullish_mas = [True,False,None]
bullish_candles = [True,False,None]
touch_lows = [True,False]

lookup_range = 250
lookup_range2 = 150
stop_range = 4500
pip_threshold = pip_thresholds[1]
support_low = True
bullish_ma = None
bullish_candle = False
candle_size = candle_sizes[2]
touch_low = touch_lows[0]
midpoint_offset = midpoint_offsets[0]
bound_pips = bound_pips_[3]


def return_random_list_element(lst):
    return lst[random.randint(0,len(lst) - 1)]
def generate_random_param_list():
    lookup_range = return_random_list_element(lookup_ranges)
    lookup_range2 = return_random_list_element(lookup_ranges2)
    stop_range = return_random_list_element(stop_ranges)
    pip_threshold = return_random_list_element(pip_thresholds)
    support_low = return_random_list_element(support_lows)
    bullish_ma = return_random_list_element(bullish_mas)
    bullish_candle = return_random_list_element(bullish_candles)
    candle_size = return_random_list_element(candle_sizes)
    touch_low = return_random_list_element(touch_lows)
    midpoint_offset = return_random_list_element(midpoint_offsets)
    bound_pips = return_random_list_element(bound_pips_)
    param_check_list = [lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips]
    return param_check_list
        
        
param_check_lists = []
keep_looping = True

while keep_looping:
    lookup_range = return_random_list_element(lookup_ranges)
    lookup_range2 = return_random_list_element(lookup_ranges2)
    stop_range = return_random_list_element(stop_ranges)
    pip_threshold = return_random_list_element(pip_thresholds)
    support_low = return_random_list_element(support_lows)
    bullish_ma = return_random_list_element(bullish_mas)
    bullish_candle = return_random_list_element(bullish_candles)
    candle_size = return_random_list_element(candle_sizes)
    touch_low = return_random_list_element(touch_lows)
    midpoint_offset = return_random_list_element(midpoint_offsets)
    bound_pips = return_random_list_element(bound_pips_)
    
    param_check_list = [lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips]
    if param_check_list not in param_check_lists:
        
        
        
        param_check_lists.append(param_check_list)
    if len(param_check_lists) > 10:
        keep_looping = False
param_check_lists

# %%
random.randint(0,10)

# %%
def generate_random_param_list():
    def return_random_list_element(lst):
        return lst[random.randint(0,len(lst) - 1)]
    # param loop
    # PARAM DEFINITON
    if 'JPY' in pair:
        pip_thresholds = [.3,.5,.7]
        sls = [.05,.075,.1,.125,.15,.2,.25]
        tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
        candle_sizes = [.05,.075,.1,.15]
        midpoint_offsets = [0,-.05,.05,-.1,.1,-.15,.15,-.25,.25]
        bound_pips_ = [.025,.05,.075,.1,.15]
    else:
        pip_thresholds = [.003,.005,.007]
        sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
        tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
        candle_sizes = [.0005,.00075,.001,.0015]
        midpoint_offsets = [0,-.0005,.0005,-.001,.001,-.0015,.0015,-.0025,.0025]
        bound_pips_ = [.00025,.0005,.00075,.001,.0015]

    lookup_ranges = [100,288,400,600]
    lookup_ranges2 = [100,288,400,600]    
    stop_ranges = [1000,3000,6000,8000]

    support_lows = [True,False]
    bullish_mas = [True,False,None]
    bullish_candles = [True,False,None]
    touch_lows = [True,False]
    
    lookup_range = return_random_list_element(lookup_ranges)
    lookup_range2 = return_random_list_element(lookup_ranges2)
    stop_range = return_random_list_element(stop_ranges)
    pip_threshold = return_random_list_element(pip_thresholds)
    support_low = return_random_list_element(support_lows)
    bullish_ma = return_random_list_element(bullish_mas)
    bullish_candle = return_random_list_element(bullish_candles)
    candle_size = return_random_list_element(candle_sizes)
    touch_low = return_random_list_element(touch_lows)
    midpoint_offset = return_random_list_element(midpoint_offsets)
    bound_pips = return_random_list_element(bound_pips_)
    param_check_list = [lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips]
    
    return param_check_list,lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips

param_check_lists = []

checker = 0
while checker == 0:
    param_check_list,lookup_range,lookup_range2,stop_range,pip_threshold,support_low,bullish_ma,bullish_candle,candle_size,touch_low,midpoint_offset,bound_pips = generate_random_param_list()
    if param_check_list not in param_check_lists:
        param_check_lists.append(param_check_list)
        
        checker = 1
        
param_check_lists

# %%
x = None
if x == True:
    print('1')
if x == False:
    print('2')
else:
    print('3')

# %%
if 'JPY' in pair:
    pip_threshold = .3
    pip_threshold = .1
    pip_threshold2 = 0
    sls = [.05,.075,.1,.125,.15,.2,.25]
    tps = [.1,.15,.2,.25,.3,.4,.5,.7,.9,1.1,1.3]
else:
    pip_threshold = .005
    pip_threshold2 = .0025
    sls = [.0005,.00075,.001,.00125,.0015,.002,.0025]
    tps = [.001,.0015,.002,.0025,.003,.004,.005,.007,.009,.011,.013]  
#pip_threshold2s = [.0005,.001,.0015,.002,.0025]
#pip_thresholds = [.003,.005,.0075]
#lookup_ranges = [500,1000,1500,2000,2500]
#lookup_range2s = [500,1000,1500,2000,2500]
#stop_ranges = [12500,10000,7500,5000,2500]


cols = [
    'instrument'
    ,'timeframe'
    ,'buy_or_sell'
    ,'trade_strategy'
   ,'median_sim_ending_val'
    ,'starting_val'
    ,'sl'
    ,'tp'
    ,'RR'
    ,'win_rate'
    ,'pip_threshold'
    ,'pip_threshold2'
    ,'lookup_range'
    ,'lookup_range2'
    ,'stop_range'
    ,'num_trades'
    ,'risk_size' 
    ,'actual_number_of_trades'
    
]


lookup_range = 288 # 1 day
lookup_range = 100
lookup_range2 = 288 # 1 day
lookup_range2 = 100
stop_range = 4000

signal = 'bullish_engulfing'

signal = 'bullish_tls'
signal = 'bearish_tls'
signal = 'bearish_engulfing'
signal = 'bearish_tls'
signal = 'bullish_tls'
signal = 'bearish_engulfing'
signal = 'bullish_engulfing'



buy_or_sell = 1
df = get_support(df,lookup_range = lookup_range,lookup_range2 = lookup_range2,stop_range = stop_range,
                  pip_threshold = pip_threshold,pip_threshold2 = pip_threshold2,trading_session = 'london',signal =  signal)
    

trade_strategy = 'support_indicator'
#trade_strategy = 'resistance_indicatorc'
num_trades = 400
risk_size = .01
actual_number_of_trades = df[df[trade_strategy] == 1].shape[0]
starting_val = 10000
instrument = pair
timeframe = 'M5'
temp_lst = []
for sl in sls:
    for tp in tps:
        ending_val,win_rate,wins,losses = strategy_tester_buy(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'buy',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

        ending_val,win_rate,wins,losses = strategy_tester_sell(df,col = trade_strategy,sl = sl,tp = tp,num_trades = num_trades,risk_size = risk_size,entry = 'c',pr = False)

        lst = [instrument,timeframe,'sell',trade_strategy,ending_val,starting_val,sl,tp,round(tp / sl,4),round(win_rate,4),
         pip_threshold,pip_threshold2,lookup_range,lookup_range2,stop_range,num_trades,risk_size,actual_number_of_trades]
        temp_lst.append(lst)

final_df = pd.DataFrame(temp_lst,columns = cols)
final_df = final_df.sort_values(by = 'median_sim_ending_val',ascending = False)
final_df.head(10)

# %%
print(df.columns)
